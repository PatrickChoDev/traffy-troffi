# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/patrick/Desktop/Workspace/Projects/traffy-troffi/notebooks

# %%
df = pd.read_csv("../data/bangkok_traffy.csv")

# %%
df.sample(20)
# Out:
#           ticket_id                      type  \
# 35440   2022-MG92ZW                     {ถนน}
# 742381  2024-8GWQ3N           {กีดขวาง,จราจร}
# 552526  2024-DVX4CX                     {ถนน}
# 609414  2024-BZKV8P                 {ทางเท้า}
# 780694  2025-AYEG7W         {ป้าย,เสียงรบกวน}
# 289073  2023-L8PME8                 {น้ำท่วม}
# 66013   2022-3P9H2V                        {}
# 692283  2024-ETK6ZK                     {ถนน}
# 598680  2024-KL3VFE       {จราจร,ความปลอดภัย}
# 586771  2024-9QXGC8            {กีดขวาง,ป้าย}
# 211039       J9JG87               {ถนน,จราจร}
# 287404  2023-HYMUWF             {คลอง,ต้นไม้}
# 592470  2024-9RC97C                 {ทางเท้า}
# 495652  2024-6RM8T7                {แสงสว่าง}
# 730813  2024-EL87GC             {ความปลอดภัย}
# 732119  2024-A3XAMZ    {ความปลอดภัย,แสงสว่าง}
# 559860       E2TKF6  {เสียงรบกวน,ถนน,กีดขวาง}
# 689275  2024-4C9CAT       {กีดขวาง,ร้องเรียน}
# 433419  2023-HUYHY9                {แสงสว่าง}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787026 entries, 0 to 787025
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ticket_id      778254 non-null  object
#  1   type           786929 non-null  object
#  2   organization   786455 non-null  object
#  3   comment        778254 non-null  object
#  4   photo          786911 non-null  object
#  5   photo_after    641309 non-null  object
#  6   coords         787026 non-null  object
#  7   address        778254 non-null  object
#  8   subdistrict    786460 non-null  object
#  9   district       786465 non-null  object
#  10  province       786831 non-null  object
#  11  timestamp      787026 non-null  object
#  12  state          787026 non-null  object
#  13  star           274097 non-null  float64
#  14  count_reopen   787026 non-null  int64
#  15  last_activity  787026 non-null  object
# dtypes: float64(1), int64(1), object(14)
# ...

# %%
df.count()
# Out:
# ticket_id        778254
# type             786929
# organization     786455
# comment          778254
# photo            786911
# photo_after      641309
# coords           787026
# address          778254
# subdistrict      786460
# district         786465
# province         786831
# timestamp        787026
# state            787026
# star             274097
# count_reopen     787026
# last_activity    787026
# dtype: int64

# %%
df.sample()
# Out:
#           ticket_id                        type  \
# 610604  2024-CCL4MV  {สอบถาม,เสนอแนะ,ความสะอาด}
#
#                                  organization  \
# 610604  เขตบางนา,ฝ่ายรักษาความสะอาดฯ เขตบางนา
#
#                                                   comment  \
# 610604  อยากรบกวนสอบถามค่ะ ถ้าขยะบ้านเรือน ประเภทกิ่งไ...
#
#                                                     photo  \
# 610604  https://storage.googleapis.com/traffy_public_b...
#
#                                               photo_after              coords  \
# 610604  https://storage.googleapis.com/traffy_public_b...  100.61767,13.65747
#
#                                                   address subdistrict  \
# 610604  44/23 ซ. ลาซาล 32 บางนาใต้ เขตบางนา กรุงเทพมหา...    บางนาใต้
#
#        district       province                      timestamp      state  \
# 610604    บางนา  กรุงเทพมหานคร  2024-06-27 11:12:50.969242+00  เสร็จสิ้น
#
#         star  count_reopen                  last_activity
# ...
