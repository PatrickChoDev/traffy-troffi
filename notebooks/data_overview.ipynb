# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/patrick/Desktop/Workspace/Projects/traffy-troffi/notebooks

# %%
df = pd.read_csv("../data/bangkok_traffy.csv")

# %%
df.sample(20)
# Out:
#           ticket_id                     type  \
# 261357  2023-HNG6LM                       {}
# 665047  2024-4FG8UG          {กีดขวาง,จราจร}
# 201391       XFTTFU         {ถนน,เสียงรบกวน}
# 287383  2023-ZELP32               {แสงสว่าง}
# 155971  2022-6UX3DB                {น้ำท่วม}
# 506833       H6Y3BK                    {ถนน}
# 537461  2024-9PACWN  {จราจร,ความปลอดภัย,ถนน}
# 396782  2023-P6V8VU                       {}
# 490151  2024-BEPBYK     {สะพาน,แสงสว่าง,ถนน}
# 309942  2023-MY27K2               {ป้าย,ถนน}
# 185335  2022-7DFYN4                {กีดขวาง}
# 164079  2022-G9XBVG                {ทางเท้า}
# 139391  2022-NA7Z8F                   {คลอง}
# 637039       8ELJZC           {ถนน,แสงสว่าง}
# 621618  2024-NLRZR7      {ทางเท้า,ร้องเรียน}
# 456687  2023-MUM429                {ทางเท้า}
# 77012   2022-P7QGA9                       {}
# 314245  2023-B3HKMR                    {ถนน}
# 557572  2024-HGGADB          {ความสะอาด,ถนน}
# 377696  2023-E8CR2E      {ความปลอดภัย,สายไฟ}
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787026 entries, 0 to 787025
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ticket_id      778254 non-null  object
#  1   type           786929 non-null  object
#  2   organization   786455 non-null  object
#  3   comment        778254 non-null  object
#  4   photo          786911 non-null  object
#  5   photo_after    641309 non-null  object
#  6   coords         787026 non-null  object
#  7   address        778254 non-null  object
#  8   subdistrict    786460 non-null  object
#  9   district       786465 non-null  object
#  10  province       786831 non-null  object
#  11  timestamp      787026 non-null  object
#  12  state          787026 non-null  object
#  13  star           274097 non-null  float64
#  14  count_reopen   787026 non-null  int64
#  15  last_activity  787026 non-null  object
# dtypes: float64(1), int64(1), object(14)
# ...

# %%
df.count()
# Out:
# ticket_id        778254
# type             786929
# organization     786455
# comment          778254
# photo            786911
# photo_after      641309
# coords           787026
# address          778254
# subdistrict      786460
# district         786465
# province         786831
# timestamp        787026
# state            787026
# star             274097
# count_reopen     787026
# last_activity    787026
# dtype: int64
