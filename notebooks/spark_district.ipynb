# %%
# %load_ext dotenv
# %dotenv

# %%
import logging
import os
from typing import Optional

from pyspark.sql import SparkSession

# Setup basic logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


class SimpleSparkSession:
    """Simple Spark session builder for Jupyter notebooks"""

    def __init__(
            self,
            app_name="Jupyter Spark Session",
            master="local[*]",
            spark_config=None,
            enable_hive_support=False,
            # S3 configuration
            s3_bucket_name=None,
            s3_endpoint=None,
            s3_access_key=None,
            s3_secret_key=None,
            s3_region="us-east-1",
            s3_path_style_access=True,
            # PostgreSQL configuration
            postgres_config=None,
            # Package configuration
            packages=None
    ):
        self.app_name = app_name
        self.master = master
        self.spark_config = spark_config or {}
        self.enable_hive_support = enable_hive_support

        # S3 config
        self.s3_bucket_name = s3_bucket_name
        self.s3_endpoint = s3_endpoint
        self.s3_access_key = s3_access_key
        self.s3_secret_key = s3_secret_key
        self.s3_region = s3_region
        self.s3_path_style_access = s3_path_style_access

        # PostgreSQL config
        self.postgres_config = postgres_config
        self.jdbc_driver_path: Optional[str] = None

        # Packages
        self.packages = packages or []

        self._session = None

    def build_session(self):
        """Build and return a SparkSession"""
        if self._session is not None:
            return self._session

        # Start building the session
        builder = SparkSession.builder.appName(self.app_name).master(self.master)

        builder = builder.config("spark.sql.execution.arrow.pyspark.enabled", "true") \
            .config("spark.driver.extraJavaOptions", "-Djava.security.manager=allow") \
            .config("spark.executor.extraJavaOptions", "-Djava.security.manager=allow") \
 \
            # Add Hive support if requested
        if self.enable_hive_support:
            builder = builder.enableHiveSupport()

        if self.jdbc_driver_path:
            builder = builder.config("spark.driver.extraClassPath", self.jdbc_driver_path)
            builder = builder.config("spark.executor.extraClassPath", self.jdbc_driver_path)

        # Add all configuration options
        for key, value in self.spark_config.items():
            builder = builder.config(key, value)

        # Configure packages
        if self.packages:
            packages = ",".join(self.packages)
            builder = builder.config("spark.jars.packages", packages)

        # Add S3 configuration if credentials provided
        if self.s3_access_key and self.s3_secret_key:
            builder = builder.config("spark.hadoop.fs.s3a.access.key", self.s3_access_key)
            builder = builder.config("spark.hadoop.fs.s3a.secret.key", self.s3_secret_key)
            builder = builder.config("spark.hadoop.fs.s3a.aws.credentials.provider",
                                     "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider")

            # Config for non-AWS S3
            if self.s3_endpoint:
                builder = builder.config("spark.hadoop.fs.s3a.endpoint", self.s3_endpoint)
                builder = builder.config("spark.hadoop.fs.s3a.endpoint.region", self.s3_region)

            # Path style access for non-AWS implementations
            if self.s3_path_style_access:
                builder = builder.config("spark.hadoop.fs.s3a.path.style.access", "true")
                builder = builder.config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false")
                builder = builder.config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
                builder = builder.config("spark.hadoop.fs.s3a.multiobjectdelete.enable", "false")

        # Build the session
        logger.info(f"Building Spark session with app name: {self.app_name}, master: {self.master}")
        self._session = builder.getOrCreate()

        return self._session

    def get_session(self):
        """Get the current SparkSession or create a new one"""
        return self.build_session()

    def stop_session(self):
        """Stop the current Spark session if it exists"""
        if self._session is not None:
            self._session.stop()
            self._session = None
            logger.info("Spark session stopped")

# %%
spark = SimpleSparkSession(
    app_name="Data Analysis Notebook",
    packages=[
        "org.postgresql:postgresql:42.5.4",
        "org.apache.hadoop:hadoop-aws:3.3.4",
        "com.amazonaws:aws-java-sdk-bundle:1.12.426"
    ],
    s3_access_key=os.getenv("S3_ACCESS_KEY"),
    s3_secret_key=os.getenv("S3_SECRET_KEY"),
    s3_endpoint=os.getenv("S3_ENDPOINT"),
    s3_region="garage",
    s3_path_style_access=True,
    postgres_config={
        "user": os.getenv("POSTGRES_USER"),
        "password": os.getenv("POSTGRES_PASSWORD"),
        "driver": "org.postgresql.Driver",
        "currentSchema": "public"
    },
    enable_hive_support=False,
    s3_bucket_name="traffy-troffi"
).get_session()

# %%
df = spark.read.jdbc(table='traffy_fondue',
                     url="jdbc:postgresql://localhost:5432/traffy-troffi",
                     properties={"user": "postgres", "password": "troffi",
                                 "driver": "org.postgresql.Driver",
                                 "currentSchema": "public"}
                     )
df.printSchema()

# %%
import pyspark.sql.functions as F

# %%
df.filter((F.col("district") == 'ราชเทวี') & (F.array_contains('categories', 'ถนน'))).show()

# %%
short_df = df.sample(0.01)
short_df.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StructType, StructField, StringType
from shapely.geometry import Point
import geopandas as gpd

# Initialize Spark session
spark = SparkSession.builder.appName("GeospatialProcessing").getOrCreate()

# Define return schema for the UDF with two fields
return_schema = StructType([
    StructField("e_subdistrict", StringType(), True),
    StructField("e_district", StringType(), True)
])


# Define function to check if a point is in polygon
def point_in_region(lat, lon, regions_list):
    if lat is None or lon is None:
        return None, None

    try:
        point = Point(float(lon), float(lat))
        for region in regions_list:
            if region["geometry"].contains(point):
                # Return subdistrict and district as a tuple
                return (
                    region["properties"]["SNAME"].replace("แขวง", "").strip(),
                    region["properties"]["DNAME"].replace("เขต", "").strip()
                )
        return None, None
    except Exception as e:
        print(f"Error: {str(e)}")
        return None, None


# Read regions from a file
regions_gdf = gpd.read_file("../data/subdistricts.geojson")

# Convert to a format that can be serialized and broadcast
regions_data = []
for _, region in regions_gdf.iterrows():
    # Convert to a simpler dict structure
    properties = {}
    for key, value in region.items():
        if key != 'geometry':
            properties[key] = value

    regions_data.append({
        "geometry": region.geometry,
        "properties": properties
    })

# Broadcast the region data to all workers
regions_broadcast = spark.sparkContext.broadcast(regions_data)


# Create UDF that returns a struct with two fields
def check_point_wrapper(lat, lon):
    result = point_in_region(lat, lon, regions_broadcast.value)
    return result


# Register UDF with the struct return type
point_in_region_udf = udf(check_point_wrapper, return_schema)

# Apply the UDF to find a region for each point
result_df = short_df.withColumn(
    "location_info",
    point_in_region_udf(short_df["latitude"], short_df["longitude"])
)

# Extract the struct fields into separate columns
final_df = result_df.select(
    "*",
    result_df["location_info.e_subdistrict"].alias("e_subdistrict"),
    result_df["location_info.e_district"].alias("e_district")
).drop("location_info")

# Show results
final_df.show()
# Out:
# +-----------+--------------------+--------------------+--------------------+--------------------+--------+---------+---------+--------------+--------------------+-----------------+--------------+----------+
# |  ticket_id|           complaint|           timestamp|               image|         image_after|latitude|longitude| district|   subdistrict|          categories|   categories_idx| e_subdistrict|e_district|
# +-----------+--------------------+--------------------+--------------------+--------------------+--------+---------+---------+--------------+--------------------+-----------------+--------------+----------+
# |2024-8G9PBH|ขอลอกท่อรามอินทรา...|2024-08-08 07:40:...|https://storage.g...|https://storage.g...|13.86775|100.61015|   บางเขน|    อนุสาวรีย์|       [ท่อระบายน้ำ]|           [11.0]|    อนุสาวรีย์|    บางเขน|
# |2024-A23C77|ทางก่อสร้างแจ้งว่...|2024-05-01 11:47:...|https://storage.g...|https://storage.g...|13.76625|100.34874| ทวีวัฒนา|      ทวีวัฒนา|       [ความปลอดภัย]|            [5.0]|      ทวีวัฒนา|  ทวีวัฒนา|
# |2024-P8YEBQ|น้ำสกปรก ส่งกลิ่น...|2024-06-15 20:35:...|https://storage.g...|https://storage.g...|13.72781|100.53191|   บางรัก|     สุริยวงศ์|[ทางเท้า, ความสะอ...| [10.0, 6.0, 9.0]|     สุริยวงศ์|    บางรัก|
# |2024-EAEX2R|มีสิ่งปลูกสร้างบน...|2024-05-01 09:30:...|https://storage.g...|https://storage.g...|13.84627|100.64862|   บางเขน|       ท่าแร้ง|           [ทางเท้า]|           [10.0]|       ท่าแร้ง|    บางเขน|
# |2024-MG9KLP|โครงการก่อสร้างca...|2024-06-13 02:51:...|https://storage.g...|https://storage.g...|13.73308| 100.5233|   บางรัก|    มหาพฤฒาราม|         [ความสะอาด]|            [6.0]|    มหาพฤฒาราม|    บางรัก|
# |2024-4C4TDD|ปล่อยอุจจาระลงในถ...|2024-05-07 09:28:...|https://storage.g...|https://storage.g...|13.67571|100.41228|   บางบอน|   คลองบางพราน|               [ถนน]|            [9.0]|        บางบอน|    บางบอน|
# |2024-9XZYDC|รุกล้ำทางเท้า วาง...|2024-05-06 02:26:...|https://storage.g...|https://storage.g...|13.92667| 100.5914| ดอนเมือง|         สีกัน|  [ทางเท้า, กีดขวาง]|      [10.0, 2.0]|         สีกัน|  ดอนเมือง|
# |2024-9W3GFG|รบกวนมาตัดต้นไม้ ...|2024-05-16 03:15:...|https://storage.g...|https://storage.g...|13.81895|100.65488|  บึงกุ่ม|      คลองกุ่ม|  [แสงสว่าง, ต้นไม้]|      [23.0, 8.0]|     นวลจันทร์|   บึงกุ่ม|
# |2024-K3R8TM|แสงสว่างทางข้ามม้...|2024-08-22 10:05:...|https://storage.g...|https://storage.g...|13.74725|100.52364|  ปทุมวัน|      รองเมือง|     [ถนน, แสงสว่าง]|      [9.0, 23.0]|      รองเมือง|   ปทุมวัน|
# |2024-7LNEAM|กระเบื้องฟุตบาททา...|2024-05-09 08:52:...|https://storage.g...|https://storage.g...|13.76018|100.73127|ลาดกระบัง|คลองสองต้นนุ่น|[ท่อระบายน้ำ, ทาง...|[11.0, 10.0, 9.0]|คลองสองต้นนุ่น| ลาดกระบัง|
# |2024-DHTEKA|ไฟส่องสว่างดับมาเ...|2024-09-21 09:26:...|https://storage.g...|https://storage.g...| 13.7132|100.53001|     สาทร|       ยานนาวา|          [แสงสว่าง]|           [23.0]|    ทุ่งวัดดอน|      สาทร|
# |2024-F6VZRC|กองขยะบนทางเท้า ท...|2024-05-08 08:19:...|https://storage.g...|https://storage.g...|13.73324|100.56272|  คลองเตย|       คลองเตย|[ทางเท้า, ความสะอาด]|      [10.0, 6.0]|       คลองเตย|   คลองเตย|
# |2024-HHH69T|ทางลอดอุโมงศรีนคร...|2024-07-22 02:26:...|https://storage.g...|https://storage.g...|13.73738|100.64146|  สวนหลวง|       สวนหลวง|        [ถนน, จราจร]|       [9.0, 7.0]|       สวนหลวง|   สวนหลวง|
# |2024-G4E87E|จอด ขับขี่ซื้อน้ำ...|2024-05-08 05:44:...|https://storage.g...|https://storage.g...|13.79068|  100.544|    พญาไท|      สามเสนใน|           [ทางเท้า]|           [10.0]|      สามเสนใน|     พญาไท|
# |2024-3GG4AP|ไฟส่องทางไม่สว่าง...|2024-05-29 04:22:...|https://storage.g...|https://storage.g...|13.69131|100.50059|บางคอแหลม|     บางคอแหลม|       [ความปลอดภัย]|            [5.0]|     บางคอแหลม| บางคอแหลม|
# |2024-HP4FZC|ขบวนงานบวชทำรถติด...|2024-05-07 02:43:...|https://storage.g...|https://storage.g...|13.72087| 100.4771|   ธนบุรี|       ตลาดพลู|        [จราจร, ถนน]|       [7.0, 9.0]|       ตลาดพลู|    ธนบุรี|
# |2024-EB9K76|ฟุตบาททางเดินมีหล...|2024-07-25 07:52:...|https://storage.g...|https://storage.g...|13.80395|100.55359|  จตุจักร|       จตุจักร|           [ทางเท้า]|           [10.0]|       จตุจักร|   จตุจักร|
# |2024-FWYHCC|รถขนส่งขับรถเข้าซ...|2024-05-05 02:22:...|https://storage.g...|https://storage.g...|13.83674|100.63943|  บึงกุ่ม|     นวลจันทร์|       [ท่อระบายน้ำ]|           [11.0]|     นวลจันทร์|   บึงกุ่ม|
# |2024-NURXAK|ฐานปูนกีดขวางเเละ...|2024-06-04 05:19:...|https://storage.g...|https://storage.g...|13.76007|100.50713|   พระนคร|     บ้านพานถม|[กีดขวาง, ความปลอ...|       [2.0, 5.0]|     บ้านพานถม|    พระนคร|
# |2024-M74HUC|         ฟุตบาทชำรุด|2024-09-19 04:07:...|https://storage.g...|https://storage.g...|13.70506|100.59637|  คลองเตย|       พระโขนง|           [ทางเท้า]|           [10.0]|       พระโขนง|   คลองเตย|
# +-----------+--------------------+--------------------+--------------------+--------------------+--------+---------+---------+--------------+--------------------+-----------------+--------------+----------+
# only showing top 20 rows

# %%
regions_data
# Out:
# [{'geometry': <POLYGON ((100.653 13.886, 100.653 13.886, 100.653 13.886, 100.653 13.886, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 64,
#    'DCODE': '1005',
#    'AREA_': 22922521.274935,
#    'SUB_CODE': '0508',
#    'PERIMETER': 24078.875,
#    'DNAME': 'เขตบางเขน',
#    'OBJECTID': 52.0,
#    'SNAME': 'แขวงท่าแร้ง',
#    'SCODE': '100508',
#    'SCODE_BMA': '100502',
#    'PCODE': '10',
#    'SUBDIST_': 65,
#    'water': 3007}},
#  {'geometry': <POLYGON ((100.788 13.879, 100.788 13.879, 100.788 13.879, 100.788 13.879, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 66,
#    'DCODE': '1046',
#    'AREA_': 17349298.283536,
#    'SUB_CODE': '4605',
#    'PERIMETER': 19713.927734,
#    'DNAME': 'เขตคลองสามวา',
#    'OBJECTID': 55.0,
#    'SNAME': 'แขวงทรายกองดินใต้',
#    'SCODE': '104605',
#    'SCODE_BMA': '104605',
#    'PCODE': '10',
#    'SUBDIST_': 68,
#    'water': 6214}},
#  {'geometry': <POLYGON ((100.763 13.869, 100.763 13.869, 100.763 13.869, 100.763 13.869, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 69,
#    'DCODE': '1046',
#    'AREA_': 10646618.816971,
#    'SUB_CODE': '4604',
#    'PERIMETER': 15812.43457,
#    'DNAME': 'เขตคลองสามวา',
#    'OBJECTID': 57.0,
#    'SNAME': 'แขวงทรายกองดิน',
#    'SCODE': '104604',
#    'SCODE_BMA': '104604',
#    'PCODE': '10',
#    'SUBDIST_': 70,
#    'water': 3462}},
#  {'geometry': <POLYGON ((100.543 13.763, 100.543 13.763, 100.544 13.763, 100.544 13.763, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 143,
#    'DCODE': '1037',
#    'AREA_': 2474955.955011,
#    'SUB_CODE': '3704',
#    'PERIMETER': 7526.941895,
#    'DNAME': 'เขตราชเทวี',
#    'OBJECTID': 1.0,
#    'SNAME': 'แขวงมักกะสัน',
#    'SCODE': '103704',
#    'SCODE_BMA': '103704',
#    'PCODE': '10',
#    'SUBDIST_': 155,
#    'water': 190}},
#  {'geometry': <POLYGON ((100.5 13.762, 100.499 13.76, 100.499 13.76, 100.499 13.76, 100.49...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 145,
#    'DCODE': '1001',
#    'AREA_': 187945.477202,
#    'SUB_CODE': '0108',
#    'PERIMETER': 1979.035767,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 2.0,
#    'SNAME': 'แขวงตลาดยอด',
#    'SCODE': '100108',
#    'SCODE_BMA': '100108',
#    'PCODE': '10',
#    'SUBDIST_': 156,
#    'water': 1}},
#  {'geometry': <POLYGON ((100.473 13.763, 100.474 13.762, 100.474 13.762, 100.475 13.761, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 144,
#    'DCODE': '1020',
#    'AREA_': 2305540.472713,
#    'SUB_CODE': '2005',
#    'PERIMETER': 6753.913086,
#    'DNAME': 'เขตบางกอกน้อย',
#    'OBJECTID': 3.0,
#    'SNAME': 'แขวงบ้านช่างหล่อ',
#    'SCODE': '102005',
#    'SCODE_BMA': '102002',
#    'PCODE': '10',
#    'SUBDIST_': 157,
#    'water': 28}},
#  {'geometry': <POLYGON ((100.49 13.76, 100.49 13.76, 100.49 13.76, 100.49 13.761, 100.49 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 146,
#    'DCODE': '1001',
#    'AREA_': 1518890.983743,
#    'SUB_CODE': '0101',
#    'PERIMETER': 5243.482422,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 4.0,
#    'SNAME': 'แขวงพระบรมมหาราชวัง',
#    'SCODE': '100101',
#    'SCODE_BMA': '100101',
#    'PCODE': '10',
#    'SUBDIST_': 158,
#    'water': 146}},
#  {'geometry': <POLYGON ((100.528 13.774, 100.528 13.774, 100.528 13.774, 100.528 13.774, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 132,
#    'DCODE': '1037',
#    'AREA_': 2491159.864361,
#    'SUB_CODE': '3701',
#    'PERIMETER': 6454.044434,
#    'DNAME': 'เขตราชเทวี',
#    'OBJECTID': 22.0,
#    'SNAME': 'แขวงทุ่งพญาไท',
#    'SCODE': '103701',
#    'SCODE_BMA': '103701',
#    'PCODE': '10',
#    'SUBDIST_': 144,
#    'water': 49}},
#  {'geometry': <POLYGON ((100.504 13.77, 100.504 13.77, 100.504 13.769, 100.503 13.769, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 134,
#    'DCODE': '1001',
#    'AREA_': 504808.586887,
#    'SUB_CODE': '0112',
#    'PERIMETER': 3049.21582,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 23.0,
#    'SNAME': 'แขวงวัดสามพระยา',
#    'SCODE': '100112',
#    'SCODE_BMA': '100112',
#    'PCODE': '10',
#    'SUBDIST_': 146,
#    'water': 79}},
#  {'geometry': <POLYGON ((100.501 13.767, 100.501 13.767, 100.501 13.767, 100.502 13.767, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 137,
#    'DCODE': '1001',
#    'AREA_': 410806.062715,
#    'SUB_CODE': '0110',
#    'PERIMETER': 3156.627197,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 26.0,
#    'SNAME': 'แขวงบ้านพานถม',
#    'SCODE': '100110',
#    'SCODE_BMA': '100110',
#    'PCODE': '10',
#    'SUBDIST_': 149,
#    'water': 2}},
#  {'geometry': <POLYGON ((100.54 13.766, 100.54 13.766, 100.54 13.766, 100.54 13.765, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 138,
#    'DCODE': '1037',
#    'AREA_': 1225321.869323,
#    'SUB_CODE': '3702',
#    'PERIMETER': 4832.415039,
#    'DNAME': 'เขตราชเทวี',
#    'OBJECTID': 27.0,
#    'SNAME': 'แขวงถนนพญาไท',
#    'SCODE': '103702',
#    'SCODE_BMA': '103702',
#    'PCODE': '10',
#    'SUBDIST_': 150,
#    'water': 39}},
#  {'geometry': <POLYGON ((100.499 13.763, 100.498 13.762, 100.498 13.762, 100.498 13.762, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 139,
#    'DCODE': '1001',
#    'AREA_': 338955.925572,
#    'SUB_CODE': '0109',
#    'PERIMETER': 2436.460938,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 28.0,
#    'SNAME': 'แขวงชนะสงคราม',
#    'SCODE': '100109',
#    'SCODE_BMA': '100109',
#    'PCODE': '10',
#    'SUBDIST_': 151,
#    'water': 35}},
#  {'geometry': <POLYGON ((100.475 13.766, 100.476 13.765, 100.477 13.765, 100.477 13.764, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 140,
#    'DCODE': '1020',
#    'AREA_': 1407951.814959,
#    'SUB_CODE': '2004',
#    'PERIMETER': 6696.673828,
#    'DNAME': 'เขตบางกอกน้อย',
#    'OBJECTID': 29.0,
#    'SNAME': 'แขวงศิริราช',
#    'SCODE': '102004',
#    'SCODE_BMA': '102001',
#    'PCODE': '10',
#    'SUBDIST_': 152,
#    'water': 113}},
#  {'geometry': <POLYGON ((100.595 13.764, 100.595 13.764, 100.595 13.764, 100.595 13.764, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 141,
#    'DCODE': '1017',
#    'AREA_': 6112084.667968,
#    'SUB_CODE': '1702',
#    'PERIMETER': 11903.216797,
#    'DNAME': 'เขตห้วยขวาง',
#    'OBJECTID': 30.0,
#    'SNAME': 'แขวงบางกะปิ',
#    'SCODE': '101702',
#    'SCODE_BMA': '101702',
#    'PCODE': '10',
#    'SUBDIST_': 153,
#    'water': 577}},
#  {'geometry': <POLYGON ((100.512 13.761, 100.513 13.761, 100.513 13.76, 100.513 13.76, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 142,
#    'DCODE': '1008',
#    'AREA_': 456478.852783,
#    'SUB_CODE': '0805',
#    'PERIMETER': 3104.775879,
#    'DNAME': 'เขตป้อมปราบศัตรูพ่าย',
#    'OBJECTID': 31.0,
#    'SNAME': 'แขวงวัดโสมนัส',
#    'SCODE': '100805',
#    'SCODE_BMA': '100805',
#    'PCODE': '10',
#    'SUBDIST_': 154,
#    'water': 4}},
#  {'geometry': <POLYGON ((100.729 13.922, 100.729 13.922, 100.729 13.922, 100.729 13.922, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 45,
#    'DCODE': '1046',
#    'AREA_': 28852917.338431,
#    'SUB_CODE': '4601',
#    'PERIMETER': 24228.171875,
#    'DNAME': 'เขตคลองสามวา',
#    'OBJECTID': 33.0,
#    'SNAME': 'แขวงสามวาตะวันตก',
#    'SCODE': '104601',
#    'SCODE_BMA': '104601',
#    'PCODE': '10',
#    'SUBDIST_': 46,
#    'water': 7513}},
#  {'geometry': <POLYGON ((100.623 13.92, 100.623 13.92, 100.623 13.919, 100.623 13.919, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 46,
#    'DCODE': '1042',
#    'AREA_': 11970095.825165,
#    'SUB_CODE': '4203',
#    'PERIMETER': 15873.674805,
#    'DNAME': 'เขตสายไหม',
#    'OBJECTID': 34.0,
#    'SNAME': 'แขวงคลองถนน',
#    'SCODE': '104203',
#    'SCODE_BMA': '104203',
#    'PCODE': '10',
#    'SUBDIST_': 47,
#    'water': 1114}},
#  {'geometry': <POLYGON ((100.687 13.916, 100.687 13.916, 100.687 13.916, 100.687 13.916, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 48,
#    'DCODE': '1042',
#    'AREA_': 15138325.827563,
#    'SUB_CODE': '4202',
#    'PERIMETER': 17660.068359,
#    'DNAME': 'เขตสายไหม',
#    'OBJECTID': 36.0,
#    'SNAME': 'แขวงออเงิน',
#    'SCODE': '104202',
#    'SCODE_BMA': '104202',
#    'PCODE': '10',
#    'SUBDIST_': 49,
#    'water': 3190}},
#  {'geometry': <POLYGON ((100.559 13.914, 100.559 13.914, 100.559 13.914, 100.559 13.914, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 50,
#    'DCODE': '1041',
#    'AREA_': 16765050.872992,
#    'SUB_CODE': '4101',
#    'PERIMETER': 18894.78125,
#    'DNAME': 'เขตหลักสี่',
#    'OBJECTID': 38.0,
#    'SNAME': 'แขวงทุ่งสองห้อง',
#    'SCODE': '104101',
#    'SCODE_BMA': '104101',
#    'PCODE': '10',
#    'SUBDIST_': 51,
#    'water': 1303}},
#  {'geometry': <POLYGON ((100.901 13.899, 100.901 13.899, 100.901 13.899, 100.901 13.899, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 55,
#    'DCODE': '1003',
#    'AREA_': 30602189.566256,
#    'SUB_CODE': '0302',
#    'PERIMETER': 27098.058594,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 43.0,
#    'SNAME': 'แขวงหนองจอก',
#    'SCODE': '100302',
#    'SCODE_BMA': '100302',
#    'PCODE': '10',
#    'SUBDIST_': 56,
#    'water': 11536}},
#  {'geometry': <POLYGON ((100.611 13.9, 100.609 13.896, 100.609 13.896, 100.609 13.895, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 58,
#    'DCODE': '1005',
#    'AREA_': 18035904.795996,
#    'SUB_CODE': '0502',
#    'PERIMETER': 19408.476562,
#    'DNAME': 'เขตบางเขน',
#    'OBJECTID': 44.0,
#    'SNAME': 'แขวงอนุสาวรีย์',
#    'SCODE': '100502',
#    'SCODE_BMA': '100501',
#    'PCODE': '10',
#    'SUBDIST_': 57,
#    'water': 1795}},
#  {'geometry': <POLYGON ((100.826 13.896, 100.826 13.896, 100.826 13.896, 100.826 13.896, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 57,
#    'DCODE': '1003',
#    'AREA_': 17837710.222228,
#    'SUB_CODE': '0306',
#    'PERIMETER': 17765.785156,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 46.0,
#    'SNAME': 'แขวงคู้ฝั่งเหนือ',
#    'SCODE': '100306',
#    'SCODE_BMA': '100306',
#    'PCODE': '10',
#    'SUBDIST_': 59,
#    'water': 6674}},
#  {'geometry': <POLYGON ((100.584 13.891, 100.584 13.891, 100.584 13.891, 100.584 13.891, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 61,
#    'DCODE': '1041',
#    'AREA_': 5904203.339715,
#    'SUB_CODE': '4102',
#    'PERIMETER': 12244.829102,
#    'DNAME': 'เขตหลักสี่',
#    'OBJECTID': 49.0,
#    'SNAME': 'แขวงตลาดบางเขน',
#    'SCODE': '104102',
#    'SCODE_BMA': '104102',
#    'PCODE': '10',
#    'SUBDIST_': 62,
#    'water': 213}},
#  {'geometry': <POLYGON ((100.501 13.767, 100.501 13.767, 100.502 13.767, 100.503 13.769, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 136,
#    'DCODE': '1001',
#    'AREA_': 450332.8924,
#    'SUB_CODE': '0111',
#    'PERIMETER': 2875.431396,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 25.0,
#    'SNAME': 'แขวงบางขุนพรหม',
#    'SCODE': '100111',
#    'SCODE_BMA': '100111',
#    'PCODE': '10',
#    'SUBDIST_': 148,
#    'water': 6}},
#  {'geometry': <POLYGON ((100.5 13.762, 100.503 13.76, 100.504 13.759, 100.504 13.759, 100....>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 148,
#    'DCODE': '1001',
#    'AREA_': 489661.622382,
#    'SUB_CODE': '0107',
#    'PERIMETER': 3428.18042,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 63.0,
#    'SNAME': 'แขวงบวรนิเวศ',
#    'SCODE': '100107',
#    'SCODE_BMA': '100107',
#    'PCODE': '10',
#    'SUBDIST_': 160,
#    'water': 5}},
#  {'geometry': <POLYGON ((100.452 13.76, 100.452 13.76, 100.452 13.76, 100.452 13.76, 100.4...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 149,
#    'DCODE': '1019',
#    'AREA_': 5115543.113055,
#    'SUB_CODE': '1904',
#    'PERIMETER': 14401.668945,
#    'DNAME': 'เขตตลิ่งชัน',
#    'OBJECTID': 64.0,
#    'SNAME': 'แขวงบางพรม',
#    'SCODE': '101904',
#    'SCODE_BMA': '101904',
#    'PCODE': '10',
#    'SUBDIST_': 161,
#    'water': 675}},
#  {'geometry': <POLYGON ((100.406 13.759, 100.406 13.759, 100.406 13.759, 100.407 13.759, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 151,
#    'DCODE': '1019',
#    'AREA_': 4211933.804143,
#    'SUB_CODE': '1907',
#    'PERIMETER': 13526.97168,
#    'DNAME': 'เขตตลิ่งชัน',
#    'OBJECTID': 65.0,
#    'SNAME': 'แขวงบางเชือกหนัง',
#    'SCODE': '101907',
#    'SCODE_BMA': '101906',
#    'PCODE': '10',
#    'SUBDIST_': 162,
#    'water': 678}},
#  {'geometry': <POLYGON ((100.727 13.864, 100.727 13.864, 100.728 13.865, 100.728 13.865, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 72,
#    'DCODE': '1046',
#    'AREA_': 20122065.483636,
#    'SUB_CODE': '4603',
#    'PERIMETER': 23233.662109,
#    'DNAME': 'เขตคลองสามวา',
#    'OBJECTID': 67.0,
#    'SNAME': 'แขวงบางชัน',
#    'SCODE': '104603',
#    'SCODE_BMA': '104603',
#    'PCODE': '10',
#    'SUBDIST_': 73,
#    'water': 2085}},
#  {'geometry': <POLYGON ((100.521 13.757, 100.521 13.757, 100.522 13.757, 100.524 13.756, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 153,
#    'DCODE': '1037',
#    'AREA_': 976230.127799,
#    'SUB_CODE': '3703',
#    'PERIMETER': 5393.924805,
#    'DNAME': 'เขตราชเทวี',
#    'OBJECTID': 66.0,
#    'SNAME': 'แขวงถนนเพชรบุรี',
#    'SCODE': '103703',
#    'SCODE_BMA': '103703',
#    'PCODE': '10',
#    'SUBDIST_': 163,
#    'water': 16}},
#  {'geometry': <POLYGON ((100.857 13.858, 100.857 13.858, 100.857 13.858, 100.857 13.858, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 75,
#    'DCODE': '1003',
#    'AREA_': 40001826.049417,
#    'SUB_CODE': '0301',
#    'PERIMETER': 28642.484375,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 70.0,
#    'SNAME': 'แขวงกระทุ่มราย',
#    'SCODE': '100301',
#    'SCODE_BMA': '100301',
#    'PCODE': '10',
#    'SUBDIST_': 76,
#    'water': 15407}},
#  {'geometry': <POLYGON ((100.847 13.857, 100.847 13.857, 100.847 13.857, 100.847 13.857, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 76,
#    'DCODE': '1003',
#    'AREA_': 21885580.012117,
#    'SUB_CODE': '0305',
#    'PERIMETER': 21762.679688,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 71.0,
#    'SNAME': 'แขวงโคกแฝด',
#    'SCODE': '100305',
#    'SCODE_BMA': '100305',
#    'PCODE': '10',
#    'SUBDIST_': 77,
#    'water': 6532}},
#  {'geometry': <POLYGON ((100.587 13.859, 100.587 13.859, 100.587 13.859, 100.587 13.859, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 77,
#    'DCODE': '1030',
#    'AREA_': 10679277.300574,
#    'SUB_CODE': '3001',
#    'PERIMETER': 14349.321289,
#    'DNAME': 'เขตจตุจักร',
#    'OBJECTID': 72.0,
#    'SNAME': 'แขวงลาดยาว',
#    'SCODE': '103001',
#    'SCODE_BMA': '103001',
#    'PCODE': '10',
#    'SUBDIST_': 78,
#    'water': 360}},
#  {'geometry': <POLYGON ((100.587 13.858, 100.587 13.858, 100.587 13.858, 100.587 13.858, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 300,
#    'DCODE': '1030',
#    'AREA_': 2830888.907553,
#    'SUB_CODE': '3002',
#    'PERIMETER': 8058.541504,
#    'DNAME': 'เขตจตุจักร',
#    'OBJECTID': 73.0,
#    'SNAME': 'แขวงเสนานิคม',
#    'SCODE': '103002',
#    'SCODE_BMA': '103002',
#    'PCODE': '10',
#    'SUBDIST_': 79,
#    'water': 131}},
#  {'geometry': <POLYGON ((100.669 13.857, 100.669 13.857, 100.669 13.857, 100.669 13.857, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1043',
#    'AREA_': 12631737.235475,
#    'SUB_CODE': '4302',
#    'PERIMETER': 23805.162109,
#    'DNAME': 'เขตคันนายาว',
#    'OBJECTID': 74.0,
#    'SNAME': 'แขวงรามอินทรา',
#    'SCODE': '104302',
#    'SCODE_BMA': '104302',
#    'PCODE': '10',
#    'SUBDIST_': 80,
#    'water': 1343}},
#  {'geometry': <POLYGON ((100.808 13.854, 100.808 13.853, 100.808 13.853, 100.808 13.853, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 79,
#    'DCODE': '1010',
#    'AREA_': 36250632.073139,
#    'SUB_CODE': '1002',
#    'PERIMETER': 29539.310547,
#    'DNAME': 'เขตมีนบุรี',
#    'OBJECTID': 75.0,
#    'SNAME': 'แขวงแสนแสบ',
#    'SCODE': '101002',
#    'SCODE_BMA': '101002',
#    'PCODE': '10',
#    'SUBDIST_': 81,
#    'water': 11317}},
#  {'geometry': <POLYGON ((100.619 13.849, 100.619 13.849, 100.619 13.849, 100.619 13.849, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 83,
#    'DCODE': '1038',
#    'AREA_': 6337280.199591,
#    'SUB_CODE': '3802',
#    'PERIMETER': 12102.875,
#    'DNAME': 'เขตลาดพร้าว',
#    'OBJECTID': 78.0,
#    'SNAME': 'แขวงจรเข้บัว',
#    'SCODE': '103802',
#    'SCODE_BMA': '103802',
#    'PCODE': '10',
#    'SUBDIST_': 85,
#    'water': 663}},
#  {'geometry': <POLYGON ((100.544 13.85, 100.543 13.849, 100.543 13.848, 100.543 13.847, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1029',
#    'AREA_': 6441636.312759,
#    'SUB_CODE': '2902',
#    'PERIMETER': 13154.583984,
#    'DNAME': 'เขตบางซื่อ',
#    'OBJECTID': 79.0,
#    'SNAME': 'แขวงวงศ์สว่าง',
#    'SCODE': '102902',
#    'SCODE_BMA': '102902',
#    'PCODE': '10',
#    'SUBDIST_': 86,
#    'water': 267}},
#  {'geometry': <POLYGON ((100.848 13.942, 100.848 13.938, 100.848 13.932, 100.848 13.927, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 38,
#    'DCODE': '1003',
#    'AREA_': 30862927.194901,
#    'SUB_CODE': '0303',
#    'PERIMETER': 24255.642578,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 114.0,
#    'SNAME': 'แขวงคลองสิบ',
#    'SCODE': '100303',
#    'SCODE_BMA': '100303',
#    'PCODE': '10',
#    'SUBDIST_': 38,
#    'water': 10674}},
#  {'geometry': <POLYGON ((100.564 13.934, 100.565 13.934, 100.567 13.933, 100.57 13.932, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1036',
#    'AREA_': 10689125.599662,
#    'SUB_CODE': '3604',
#    'PERIMETER': 15640.108398,
#    'DNAME': 'เขตดอนเมือง',
#    'OBJECTID': 117.0,
#    'SNAME': 'แขวงดอนเมือง',
#    'SCODE': '103604',
#    'SCODE_BMA': '103602',
#    'PCODE': '10',
#    'SUBDIST_': 41,
#    'water': 957}},
#  {'geometry': <POLYGON ((100.488 13.748, 100.488 13.748, 100.488 13.748, 100.489 13.748, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 171,
#    'DCODE': '1016',
#    'AREA_': 877768.35823,
#    'SUB_CODE': '1601',
#    'PERIMETER': 3961.935303,
#    'DNAME': 'เขตบางกอกใหญ่',
#    'OBJECTID': 120.0,
#    'SNAME': 'แขวงวัดอรุณ',
#    'SCODE': '101601',
#    'SCODE_BMA': '101601',
#    'PCODE': '10',
#    'SUBDIST_': 181,
#    'water': 50}},
#  {'geometry': <POLYGON ((100.507 13.748, 100.507 13.748, 100.507 13.748, 100.508 13.748, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 172,
#    'DCODE': '1008',
#    'AREA_': 620564.810574,
#    'SUB_CODE': '0801',
#    'PERIMETER': 3578.442627,
#    'DNAME': 'เขตป้อมปราบศัตรูพ่าย',
#    'OBJECTID': 121.0,
#    'SNAME': 'แขวงป้อมปราบ',
#    'SCODE': '100801',
#    'SCODE_BMA': '100801',
#    'PCODE': '10',
#    'SUBDIST_': 182,
#    'water': 5}},
#  {'geometry': <POLYGON ((100.413 13.748, 100.414 13.748, 100.414 13.748, 100.414 13.748, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 173,
#    'DCODE': '1022',
#    'AREA_': 2696359.454192,
#    'SUB_CODE': '2208',
#    'PERIMETER': 7681.20752,
#    'DNAME': 'เขตภาษีเจริญ',
#    'OBJECTID': 122.0,
#    'SNAME': 'แขวงคลองขวาง',
#    'SCODE': '102208',
#    'SCODE_BMA': '102205',
#    'PCODE': '10',
#    'SUBDIST_': 183,
#    'water': 266}},
#  {'geometry': <POLYGON ((100.598 13.741, 100.598 13.741, 100.598 13.741, 100.598 13.741, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 175,
#    'DCODE': '1039',
#    'AREA_': 7279671.523106,
#    'SUB_CODE': '3902',
#    'PERIMETER': 13769.921875,
#    'DNAME': 'เขตวัฒนา',
#    'OBJECTID': 123.0,
#    'SNAME': 'แขวงคลองตันเหนือ',
#    'SCODE': '103902',
#    'SCODE_BMA': '103902',
#    'PCODE': '10',
#    'SUBDIST_': 184,
#    'water': 113}},
#  {'geometry': <POLYGON ((100.504 13.747, 100.504 13.747, 100.504 13.747, 100.505 13.746, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 176,
#    'DCODE': '1013',
#    'AREA_': 497262.378073,
#    'SUB_CODE': '1302',
#    'PERIMETER': 4204.507812,
#    'DNAME': 'เขตสัมพันธวงศ์',
#    'OBJECTID': 124.0,
#    'SNAME': 'แขวงสัมพันธวงศ์',
#    'SCODE': '101302',
#    'SCODE_BMA': '101302',
#    'PCODE': '10',
#    'SUBDIST_': 185,
#    'water': 18}},
#  {'geometry': <POLYGON ((100.589 13.797, 100.589 13.797, 100.589 13.798, 100.589 13.798, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1045',
#    'AREA_': 1711966.309723,
#    'SUB_CODE': '4502',
#    'PERIMETER': 7267.47998,
#    'DNAME': 'เขตวังทองหลาง',
#    'OBJECTID': 125.0,
#    'SNAME': 'แขวงสะพานสอง',
#    'SCODE': '104502',
#    'SCODE_BMA': '104502',
#    'PCODE': '10',
#    'SUBDIST_': 113,
#    'water': 14}},
#  {'geometry': <POLYGON ((100.397 13.802, 100.398 13.802, 100.4 13.802, 100.402 13.802, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 105,
#    'DCODE': '1048',
#    'AREA_': 31759979.651217,
#    'SUB_CODE': '4802',
#    'PERIMETER': 27238.138672,
#    'DNAME': 'เขตทวีวัฒนา',
#    'OBJECTID': 126.0,
#    'SNAME': 'แขวงศาลาธรรมสพน์',
#    'SCODE': '104802',
#    'SCODE_BMA': '104802',
#    'PCODE': '10',
#    'SUBDIST_': 114,
#    'water': 4071}},
#  {'geometry': <POLYGON ((100.795 13.794, 100.795 13.794, 100.795 13.794, 100.795 13.794, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 106,
#    'DCODE': '1011',
#    'AREA_': 32911268.111986,
#    'SUB_CODE': '1104',
#    'PERIMETER': 29606.949219,
#    'DNAME': 'เขตลาดกระบัง',
#    'OBJECTID': 127.0,
#    'SNAME': 'แขวงลำปลาทิว',
#    'SCODE': '101104',
#    'SCODE_BMA': '101104',
#    'PCODE': '10',
#    'SUBDIST_': 115,
#    'water': 10095}},
#  {'geometry': <POLYGON ((100.575 13.801, 100.575 13.801, 100.575 13.8, 100.575 13.797, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 290,
#    'DCODE': '1026',
#    'AREA_': 8465909.679371,
#    'SUB_CODE': '2601',
#    'PERIMETER': 14334.78418,
#    'DNAME': 'เขตดินแดง',
#    'OBJECTID': 128.0,
#    'SNAME': 'แขวงดินแดง',
#    'SCODE': '102601',
#    'SCODE_BMA': '102601',
#    'PCODE': '10',
#    'SUBDIST_': 116,
#    'water': 84}},
#  {'geometry': <POLYGON ((100.624 13.8, 100.624 13.8, 100.624 13.8, 100.624 13.8, 100.624 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1045',
#    'AREA_': 3611755.401654,
#    'SUB_CODE': '4503',
#    'PERIMETER': 8334.639648,
#    'DNAME': 'เขตวังทองหลาง',
#    'OBJECTID': 129.0,
#    'SNAME': 'แขวงคลองเจ้าคุณสิงห์',
#    'SCODE': '104503',
#    'SCODE_BMA': '104503',
#    'PCODE': '10',
#    'SUBDIST_': 117,
#    'water': 29}},
#  {'geometry': <POLYGON ((100.426 13.8, 100.427 13.8, 100.43 13.798, 100.431 13.797, 100.43...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 108,
#    'DCODE': '1019',
#    'AREA_': 9111369.885102,
#    'SUB_CODE': '1903',
#    'PERIMETER': 13704.84082,
#    'DNAME': 'เขตตลิ่งชัน',
#    'OBJECTID': 130.0,
#    'SNAME': 'แขวงฉิมพลี',
#    'SCODE': '101903',
#    'SCODE_BMA': '101903',
#    'PCODE': '10',
#    'SUBDIST_': 118,
#    'water': 486}},
#  {'geometry': <POLYGON ((100.462 13.744, 100.462 13.744, 100.463 13.744, 100.463 13.744, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 177,
#    'DCODE': '1016',
#    'AREA_': 5420517.790788,
#    'SUB_CODE': '1602',
#    'PERIMETER': 9752.301758,
#    'DNAME': 'เขตบางกอกใหญ่',
#    'OBJECTID': 131.0,
#    'SNAME': 'แขวงวัดท่าพระ',
#    'SCODE': '101602',
#    'SCODE_BMA': '101602',
#    'PCODE': '10',
#    'SUBDIST_': 186,
#    'water': 214}},
#  {'geometry': <POLYGON ((100.824 13.827, 100.824 13.827, 100.824 13.827, 100.824 13.827, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 94,
#    'DCODE': '1003',
#    'AREA_': 33281282.021702,
#    'SUB_CODE': '0307',
#    'PERIMETER': 28739.519531,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 133.0,
#    'SNAME': 'แขวงลำผักชี',
#    'SCODE': '100307',
#    'SCODE_BMA': '100307',
#    'PCODE': '10',
#    'SUBDIST_': 99,
#    'water': 10729}},
#  {'geometry': <POLYGON ((100.568 13.827, 100.571 13.826, 100.572 13.826, 100.572 13.825, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 302,
#    'DCODE': '1030',
#    'AREA_': 5554561.412077,
#    'SUB_CODE': '3004',
#    'PERIMETER': 10300.586914,
#    'DNAME': 'เขตจตุจักร',
#    'OBJECTID': 135.0,
#    'SNAME': 'แขวงจอมพล',
#    'SCODE': '103004',
#    'SCODE_BMA': '103004',
#    'PCODE': '10',
#    'SUBDIST_': 101,
#    'water': 79}},
#  {'geometry': <POLYGON ((100.629 13.826, 100.63 13.824, 100.631 13.823, 100.632 13.822, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1027',
#    'AREA_': 4701495.222214,
#    'SUB_CODE': '2702',
#    'PERIMETER': 12656.441406,
#    'DNAME': 'เขตบึงกุ่ม',
#    'OBJECTID': 136.0,
#    'SNAME': 'แขวงนวมินทร์',
#    'SCODE': '102702',
#    'SCODE_BMA': '102702',
#    'PCODE': '10',
#    'SUBDIST_': 102,
#    'water': 191}},
#  {'geometry': <POLYGON ((100.861 13.819, 100.861 13.819, 100.861 13.819, 100.861 13.819, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 98,
#    'DCODE': '1003',
#    'AREA_': 24658754.690116,
#    'SUB_CODE': '0308',
#    'PERIMETER': 29749.783203,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 139.0,
#    'SNAME': 'แขวงลำต้อยติ่ง',
#    'SCODE': '100308',
#    'SCODE_BMA': '100308',
#    'PCODE': '10',
#    'SUBDIST_': 105,
#    'water': 9511}},
#  {'geometry': <POLYGON ((100.537 13.822, 100.537 13.822, 100.539 13.821, 100.54 13.821, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 82,
#    'DCODE': '1029',
#    'AREA_': 6444179.646479,
#    'SUB_CODE': '2901',
#    'PERIMETER': 10124.689453,
#    'DNAME': 'เขตบางซื่อ',
#    'OBJECTID': 140.0,
#    'SNAME': 'แขวงบางซื่อ',
#    'SCODE': '102901',
#    'SCODE_BMA': '102901',
#    'PCODE': '10',
#    'SUBDIST_': 106,
#    'water': 269}},
#  {'geometry': <POLYGON ((100.5 13.739, 100.5 13.739, 100.503 13.738, 100.504 13.738, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 184,
#    'DCODE': '1018',
#    'AREA_': 913201.424806,
#    'SUB_CODE': '1801',
#    'PERIMETER': 4018.768311,
#    'DNAME': 'เขตคลองสาน',
#    'OBJECTID': 60.0,
#    'SNAME': 'แขวงสมเด็จเจ้าพระยา',
#    'SCODE': '101801',
#    'SCODE_BMA': '101801',
#    'PCODE': '10',
#    'SUBDIST_': 193,
#    'water': 44}},
#  {'geometry': <POLYGON ((100.658 13.737, 100.658 13.737, 100.658 13.737, 100.658 13.737, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 185,
#    'DCODE': '1032',
#    'AREA_': 24508234.436385,
#    'SUB_CODE': '3201',
#    'PERIMETER': 22827.902344,
#    'DNAME': 'เขตประเวศ',
#    'OBJECTID': 61.0,
#    'SNAME': 'แขวงประเวศ',
#    'SCODE': '103201',
#    'SCODE_BMA': '103201',
#    'PCODE': '10',
#    'SUBDIST_': 194,
#    'water': 2658}},
#  {'geometry': <POLYGON ((100.516 13.738, 100.516 13.738, 100.516 13.738, 100.516 13.738, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 186,
#    'DCODE': '1004',
#    'AREA_': 640421.9729,
#    'SUB_CODE': '0401',
#    'PERIMETER': 3871.524658,
#    'DNAME': 'เขตบางรัก',
#    'OBJECTID': 62.0,
#    'SNAME': 'แขวงมหาพฤฒาราม',
#    'SCODE': '100401',
#    'SCODE_BMA': '100401',
#    'PCODE': '10',
#    'SUBDIST_': 195,
#    'water': 3}},
#  {'geometry': <POLYGON ((100.513 13.76, 100.516 13.762, 100.516 13.761, 100.517 13.761, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 147,
#    'DCODE': '1002',
#    'AREA_': 355068.395731,
#    'SUB_CODE': '0204',
#    'PERIMETER': 2763.337402,
#    'DNAME': 'เขตดุสิต',
#    'OBJECTID': 5.0,
#    'SNAME': 'แขวงสี่แยกมหานาค',
#    'SCODE': '100204',
#    'SCODE_BMA': '100204',
#    'PCODE': '10',
#    'SUBDIST_': 159,
#    'water': 8}},
#  {'geometry': <POLYGON ((100.609 13.954, 100.612 13.954, 100.614 13.954, 100.616 13.954, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1036',
#    'AREA_': 14389890.561956,
#    'SUB_CODE': '3605',
#    'PERIMETER': 19123.798828,
#    'DNAME': 'เขตดอนเมือง',
#    'OBJECTID': 11.0,
#    'SNAME': 'แขวงสนามบิน',
#    'SCODE': '103605',
#    'SCODE_BMA': '103603',
#    'PCODE': '10',
#    'SUBDIST_': 29,
#    'water': 3371}},
#  {'geometry': <POLYGON ((100.607 13.954, 100.607 13.952, 100.607 13.951, 100.607 13.95, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 28,
#    'DCODE': '1036',
#    'AREA_': 11612511.041212,
#    'SUB_CODE': '3602',
#    'PERIMETER': 15740.063477,
#    'DNAME': 'เขตดอนเมือง',
#    'OBJECTID': 12.0,
#    'SNAME': 'แขวงสีกัน',
#    'SCODE': '103602',
#    'SCODE_BMA': '103601',
#    'PCODE': '10',
#    'SUBDIST_': 30,
#    'water': 1044}},
#  {'geometry': <POLYGON ((100.901 13.899, 100.901 13.899, 100.901 13.899, 100.901 13.899, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 31,
#    'DCODE': '1003',
#    'AREA_': 41318415.832369,
#    'SUB_CODE': '0304',
#    'PERIMETER': 27047.417969,
#    'DNAME': 'เขตหนองจอก',
#    'OBJECTID': 14.0,
#    'SNAME': 'แขวงคลองสิบสอง',
#    'SCODE': '100304',
#    'SCODE_BMA': '100304',
#    'PCODE': '10',
#    'SUBDIST_': 32,
#    'water': 15679}},
#  {'geometry': <POLYGON ((100.622 13.95, 100.625 13.949, 100.625 13.949, 100.625 13.948, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 32,
#    'DCODE': '1042',
#    'AREA_': 16505304.512399,
#    'SUB_CODE': '4201',
#    'PERIMETER': 23899.849609,
#    'DNAME': 'เขตสายไหม',
#    'OBJECTID': 15.0,
#    'SNAME': 'แขวงสายไหม',
#    'SCODE': '104201',
#    'SCODE_BMA': '104201',
#    'PCODE': '10',
#    'SUBDIST_': 33,
#    'water': 1670}},
#  {'geometry': <POLYGON ((100.528 13.774, 100.528 13.774, 100.528 13.774, 100.528 13.774, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 129,
#    'DCODE': '1002',
#    'AREA_': 1880483.372375,
#    'SUB_CODE': '0203',
#    'PERIMETER': 6271.296875,
#    'DNAME': 'เขตดุสิต',
#    'OBJECTID': 18.0,
#    'SNAME': 'แขวงสวนจิตรลดา',
#    'SCODE': '100203',
#    'SCODE_BMA': '100203',
#    'PCODE': '10',
#    'SUBDIST_': 141,
#    'water': 288}},
#  {'geometry': <POLYGON ((100.662 13.774, 100.662 13.774, 100.662 13.774, 100.662 13.774, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 130,
#    'DCODE': '1006',
#    'AREA_': 15819931.678103,
#    'SUB_CODE': '0608',
#    'PERIMETER': 21620.839844,
#    'DNAME': 'เขตบางกะปิ',
#    'OBJECTID': 19.0,
#    'SNAME': 'แขวงหัวหมาก',
#    'SCODE': '100608',
#    'SCODE_BMA': '100602',
#    'PCODE': '10',
#    'SUBDIST_': 142,
#    'water': 1358}},
#  {'geometry': <POLYGON ((100.841 13.771, 100.841 13.771, 100.841 13.771, 100.841 13.771, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 135,
#    'DCODE': '1011',
#    'AREA_': 27840742.153521,
#    'SUB_CODE': '1105',
#    'PERIMETER': 28713.394531,
#    'DNAME': 'เขตลาดกระบัง',
#    'OBJECTID': 20.0,
#    'SNAME': 'แขวงทับยาว',
#    'SCODE': '101105',
#    'SCODE_BMA': '101105',
#    'PCODE': '10',
#    'SUBDIST_': 145,
#    'water': 9493}},
#  {'geometry': <POLYGON ((100.457 13.776, 100.458 13.775, 100.46 13.774, 100.463 13.771, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 131,
#    'DCODE': '1020',
#    'AREA_': 3953843.588711,
#    'SUB_CODE': '2007',
#    'PERIMETER': 9555.473633,
#    'DNAME': 'เขตบางกอกน้อย',
#    'OBJECTID': 21.0,
#    'SNAME': 'แขวงบางขุนศรี',
#    'SCODE': '102007',
#    'SCODE_BMA': '102004',
#    'PCODE': '10',
#    'SUBDIST_': 143,
#    'water': 511}},
#  {'geometry': <POLYGON ((100.861 13.77, 100.861 13.77, 100.861 13.77, 100.861 13.77, 100.8...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 133,
#    'DCODE': '1011',
#    'AREA_': 23181668.902059,
#    'SUB_CODE': '1106',
#    'PERIMETER': 24300.082031,
#    'DNAME': 'เขตลาดกระบัง',
#    'OBJECTID': 24.0,
#    'SNAME': 'แขวงขุมทอง',
#    'SCODE': '101106',
#    'SCODE_BMA': '101106',
#    'PCODE': '10',
#    'SUBDIST_': 147,
#    'water': 9147}},
#  {'geometry': <POLYGON ((100.529 13.733, 100.53 13.733, 100.53 13.732, 100.532 13.732, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 192,
#    'DCODE': '1004',
#    'AREA_': 770126.004872,
#    'SUB_CODE': '0405',
#    'PERIMETER': 4543.222656,
#    'DNAME': 'เขตบางรัก',
#    'OBJECTID': 200.0,
#    'SNAME': 'แขวงสี่พระยา',
#    'SCODE': '100405',
#    'SCODE_BMA': '100405',
#    'PCODE': '10',
#    'SUBDIST_': 201,
#    'water': 6}},
#  {'geometry': <POLYGON ((100.769 13.728, 100.772 13.728, 100.774 13.728, 100.775 13.728, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 193,
#    'DCODE': '1011',
#    'AREA_': 10964752.083986,
#    'SUB_CODE': '1101',
#    'PERIMETER': 20934.679688,
#    'DNAME': 'เขตลาดกระบัง',
#    'OBJECTID': 201.0,
#    'SNAME': 'แขวงลาดกระบัง',
#    'SCODE': '101101',
#    'SCODE_BMA': '101101',
#    'PCODE': '10',
#    'SUBDIST_': 202,
#    'water': 1124}},
#  {'geometry': <POLYGON ((100.515 13.732, 100.515 13.732, 100.515 13.732, 100.516 13.731, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 194,
#    'DCODE': '1004',
#    'AREA_': 481630.055108,
#    'SUB_CODE': '0404',
#    'PERIMETER': 3412.706055,
#    'DNAME': 'เขตบางรัก',
#    'OBJECTID': 202.0,
#    'SNAME': 'แขวงบางรัก',
#    'SCODE': '100404',
#    'SCODE_BMA': '100404',
#    'PCODE': '10',
#    'SUBDIST_': 203,
#    'water': 61}},
#  {'geometry': <POLYGON ((100.418 13.731, 100.418 13.731, 100.418 13.731, 100.418 13.731, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 195,
#    'DCODE': '1040',
#    'AREA_': 13005279.59778,
#    'SUB_CODE': '4002',
#    'PERIMETER': 16758.154297,
#    'DNAME': 'เขตบางแค',
#    'OBJECTID': 203.0,
#    'SNAME': 'แขวงบางแคเหนือ',
#    'SCODE': '104002',
#    'SCODE_BMA': '104002',
#    'PCODE': '10',
#    'SUBDIST_': 204,
#    'water': 1190}},
#  {'geometry': <POLYGON ((100.648 13.847, 100.648 13.847, 100.648 13.847, 100.648 13.847, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 84,
#    'DCODE': '1027',
#    'AREA_': 8573296.153179,
#    'SUB_CODE': '2703',
#    'PERIMETER': 13769.800781,
#    'DNAME': 'เขตบึงกุ่ม',
#    'OBJECTID': 80.0,
#    'SNAME': 'แขวงนวลจันทร์',
#    'SCODE': '102703',
#    'SCODE_BMA': '102703',
#    'PCODE': '10',
#    'SUBDIST_': 87,
#    'water': 440}},
#  {'geometry': <POLYGON ((100.637 13.845, 100.637 13.844, 100.637 13.844, 100.637 13.843, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 87,
#    'DCODE': '1038',
#    'AREA_': 14929201.936069,
#    'SUB_CODE': '3801',
#    'PERIMETER': 20552.642578,
#    'DNAME': 'เขตลาดพร้าว',
#    'OBJECTID': 82.0,
#    'SNAME': 'แขวงลาดพร้าว',
#    'SCODE': '103801',
#    'SCODE_BMA': '103801',
#    'PCODE': '10',
#    'SUBDIST_': 89,
#    'water': 563}},
#  {'geometry': <POLYGON ((100.737 13.837, 100.738 13.837, 100.738 13.837, 100.738 13.837, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 88,
#    'DCODE': '1010',
#    'AREA_': 24869911.821664,
#    'SUB_CODE': '1001',
#    'PERIMETER': 26988.707031,
#    'DNAME': 'เขตมีนบุรี',
#    'OBJECTID': 84.0,
#    'SNAME': 'แขวงมีนบุรี',
#    'SCODE': '101001',
#    'SCODE_BMA': '101001',
#    'PCODE': '10',
#    'SUBDIST_': 91,
#    'water': 3586}},
#  {'geometry': <POLYGON ((100.572 13.834, 100.573 13.834, 100.573 13.834, 100.573 13.834, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 301,
#    'DCODE': '1030',
#    'AREA_': 5864433.846412,
#    'SUB_CODE': '3003',
#    'PERIMETER': 10905.239258,
#    'DNAME': 'เขตจตุจักร',
#    'OBJECTID': 85.0,
#    'SNAME': 'แขวงจันทรเกษม',
#    'SCODE': '103003',
#    'SCODE_BMA': '103003',
#    'PCODE': '10',
#    'SUBDIST_': 92,
#    'water': 79}},
#  {'geometry': <POLYGON ((100.539 13.831, 100.54 13.83, 100.541 13.83, 100.541 13.83, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 303,
#    'DCODE': '1030',
#    'AREA_': 7727625.624115,
#    'SUB_CODE': '3005',
#    'PERIMETER': 13081.951172,
#    'DNAME': 'เขตจตุจักร',
#    'OBJECTID': 90.0,
#    'SNAME': 'แขวงจตุจักร',
#    'SCODE': '103005',
#    'SCODE_BMA': '103005',
#    'PCODE': '10',
#    'SUBDIST_': 97,
#    'water': 816}},
#  {'geometry': <POLYGON ((100.624 13.817, 100.625 13.817, 100.625 13.817, 100.625 13.817, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 101,
#    'DCODE': '1006',
#    'AREA_': 11767531.71381,
#    'SUB_CODE': '0601',
#    'PERIMETER': 18368.369141,
#    'DNAME': 'เขตบางกะปิ',
#    'OBJECTID': 143.0,
#    'SNAME': 'แขวงคลองจั่น',
#    'SCODE': '100601',
#    'SCODE_BMA': '100601',
#    'PCODE': '10',
#    'SUBDIST_': 109,
#    'water': 487}},
#  {'geometry': <POLYGON ((100.661 13.817, 100.661 13.817, 100.661 13.817, 100.661 13.817, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1027',
#    'AREA_': 10130215.007784,
#    'SUB_CODE': '2701',
#    'PERIMETER': 14138.486328,
#    'DNAME': 'เขตบึงกุ่ม',
#    'OBJECTID': 144.0,
#    'SNAME': 'แขวงคลองกุ่ม',
#    'SCODE': '102701',
#    'SCODE_BMA': '102701',
#    'PCODE': '10',
#    'SUBDIST_': 110,
#    'water': 978}},
#  {'geometry': <POLYGON ((100.515 13.813, 100.515 13.813, 100.515 13.813, 100.516 13.813, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 102,
#    'DCODE': '1025',
#    'AREA_': 3096962.252251,
#    'SUB_CODE': '2502',
#    'PERIMETER': 7758.409668,
#    'DNAME': 'เขตบางพลัด',
#    'OBJECTID': 145.0,
#    'SNAME': 'แขวงบางอ้อ',
#    'SCODE': '102502',
#    'SCODE_BMA': '102502',
#    'PCODE': '10',
#    'SUBDIST_': 111,
#    'water': 388}},
#  {'geometry': <POLYGON ((100.589 13.803, 100.589 13.803, 100.589 13.803, 100.589 13.803, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 103,
#    'DCODE': '1017',
#    'AREA_': 5370517.529701,
#    'SUB_CODE': '1704',
#    'PERIMETER': 12837.322266,
#    'DNAME': 'เขตห้วยขวาง',
#    'OBJECTID': 146.0,
#    'SNAME': 'แขวงสามเสนนอก',
#    'SCODE': '101704',
#    'SCODE_BMA': '101703',
#    'PCODE': '10',
#    'SUBDIST_': 112,
#    'water': 283}},
#  {'geometry': <POLYGON ((100.359 13.738, 100.359 13.738, 100.359 13.738, 100.359 13.738, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 188,
#    'DCODE': '1023',
#    'AREA_': 16835101.798795,
#    'SUB_CODE': '2303',
#    'PERIMETER': 19797.779297,
#    'DNAME': 'เขตหนองแขม',
#    'OBJECTID': 148.0,
#    'SNAME': 'แขวงหนองค้างพลู',
#    'SCODE': '102303',
#    'SCODE_BMA': '102302',
#    'PCODE': '10',
#    'SUBDIST_': 197,
#    'water': 2480}},
#  {'geometry': <POLYGON ((100.506 13.737, 100.507 13.737, 100.507 13.737, 100.507 13.737, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 187,
#    'DCODE': '1018',
#    'AREA_': 1047125.327269,
#    'SUB_CODE': '1802',
#    'PERIMETER': 5693.924316,
#    'DNAME': 'เขตคลองสาน',
#    'OBJECTID': 147.0,
#    'SNAME': 'แขวงคลองสาน',
#    'SCODE': '101802',
#    'SCODE_BMA': '101802',
#    'PCODE': '10',
#    'SUBDIST_': 196,
#    'water': 93}},
#  {'geometry': <POLYGON ((100.488 13.736, 100.488 13.736, 100.488 13.736, 100.489 13.736, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 189,
#    'DCODE': '1015',
#    'AREA_': 650225.63527,
#    'SUB_CODE': '1502',
#    'PERIMETER': 3474.703369,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 149.0,
#    'SNAME': 'แขวงหิรัญรูจี',
#    'SCODE': '101502',
#    'SCODE_BMA': '101502',
#    'PCODE': '10',
#    'SUBDIST_': 198,
#    'water': 9}},
#  {'geometry': <POLYGON ((100.457 13.734, 100.459 13.735, 100.459 13.734, 100.459 13.731, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 190,
#    'DCODE': '1022',
#    'AREA_': 1461526.508287,
#    'SUB_CODE': '2206',
#    'PERIMETER': 5183.560547,
#    'DNAME': 'เขตภาษีเจริญ',
#    'OBJECTID': 150.0,
#    'SNAME': 'แขวงบางจาก',
#    'SCODE': '102206',
#    'SCODE_BMA': '102203',
#    'PCODE': '10',
#    'SUBDIST_': 199,
#    'water': 149}},
#  {'geometry': <POLYGON ((100.566 13.733, 100.566 13.733, 100.567 13.733, 100.567 13.733, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 191,
#    'DCODE': '1033',
#    'AREA_': 1944012.857614,
#    'SUB_CODE': '3302',
#    'PERIMETER': 6260.899902,
#    'DNAME': 'เขตคลองเตย',
#    'OBJECTID': 151.0,
#    'SNAME': 'แขวงคลองตัน',
#    'SCODE': '103302',
#    'SCODE_BMA': '103302',
#    'PCODE': '10',
#    'SUBDIST_': 200,
#    'water': 34}},
#  {'geometry': <POLYGON ((100.525 13.75, 100.525 13.75, 100.525 13.75, 100.525 13.75, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 165,
#    'DCODE': '1007',
#    'AREA_': 1336696.450566,
#    'SUB_CODE': '0702',
#    'PERIMETER': 5016.493164,
#    'DNAME': 'เขตปทุมวัน',
#    'OBJECTID': 152.0,
#    'SNAME': 'แขวงวังใหม่',
#    'SCODE': '100702',
#    'SCODE_BMA': '100702',
#    'PCODE': '10',
#    'SUBDIST_': 175,
#    'water': 67}},
#  {'geometry': <POLYGON ((100.541 13.749, 100.541 13.749, 100.541 13.747, 100.541 13.746, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 166,
#    'DCODE': '1007',
#    'AREA_': 2102647.854126,
#    'SUB_CODE': '0703',
#    'PERIMETER': 6096.178223,
#    'DNAME': 'เขตปทุมวัน',
#    'OBJECTID': 153.0,
#    'SNAME': 'แขวงปทุมวัน',
#    'SCODE': '100703',
#    'SCODE_BMA': '100703',
#    'PCODE': '10',
#    'SUBDIST_': 176,
#    'water': 233}},
#  {'geometry': <POLYGON ((100.541 13.749, 100.541 13.749, 100.541 13.749, 100.541 13.749, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 167,
#    'DCODE': '1007',
#    'AREA_': 3354879.514568,
#    'SUB_CODE': '0704',
#    'PERIMETER': 8028.86377,
#    'DNAME': 'เขตปทุมวัน',
#    'OBJECTID': 154.0,
#    'SNAME': 'แขวงลุมพินี',
#    'SCODE': '100704',
#    'SCODE_BMA': '100704',
#    'PCODE': '10',
#    'SUBDIST_': 177,
#    'water': 420}},
#  {'geometry': <POLYGON ((100.55 13.748, 100.55 13.748, 100.55 13.748, 100.55 13.748, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 168,
#    'DCODE': '1039',
#    'AREA_': 2180590.966814,
#    'SUB_CODE': '3901',
#    'PERIMETER': 6644.339355,
#    'DNAME': 'เขตวัฒนา',
#    'OBJECTID': 155.0,
#    'SNAME': 'แขวงคลองเตยเหนือ',
#    'SCODE': '103901',
#    'SCODE_BMA': '103901',
#    'PCODE': '10',
#    'SUBDIST_': 178,
#    'water': 37}},
#  {'geometry': <POLYGON ((100.496 13.749, 100.497 13.748, 100.498 13.748, 100.499 13.748, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 170,
#    'DCODE': '1001',
#    'AREA_': 712862.171174,
#    'SUB_CODE': '0102',
#    'PERIMETER': 3613.944092,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 157.0,
#    'SNAME': 'แขวงวังบูรพาภิรมย์',
#    'SCODE': '100102',
#    'SCODE_BMA': '100102',
#    'PCODE': '10',
#    'SUBDIST_': 180,
#    'water': 28}},
#  {'geometry': <POLYGON ((100.464 13.731, 100.464 13.731, 100.464 13.731, 100.464 13.731, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 196,
#    'DCODE': '1022',
#    'AREA_': 1789169.756136,
#    'SUB_CODE': '2209',
#    'PERIMETER': 7074.30957,
#    'DNAME': 'เขตภาษีเจริญ',
#    'OBJECTID': 158.0,
#    'SNAME': 'แขวงปากคลองภาษีเจริญ',
#    'SCODE': '102209',
#    'SCODE_BMA': '102206',
#    'PCODE': '10',
#    'SUBDIST_': 205,
#    'water': 53}},
#  {'geometry': <POLYGON ((100.534 13.731, 100.537 13.73, 100.536 13.729, 100.536 13.729, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 197,
#    'DCODE': '1004',
#    'AREA_': 604757.945085,
#    'SUB_CODE': '0403',
#    'PERIMETER': 5005.263672,
#    'DNAME': 'เขตบางรัก',
#    'OBJECTID': 159.0,
#    'SNAME': 'แขวงสุริยวงศ์',
#    'SCODE': '100403',
#    'SCODE_BMA': '100403',
#    'PCODE': '10',
#    'SUBDIST_': 206,
#    'water': 10}},
#  {'geometry': <POLYGON ((100.609 13.786, 100.609 13.786, 100.609 13.785, 100.608 13.784, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 0,
#    'DCODE': '1045',
#    'AREA_': 4914327.123533,
#    'SUB_CODE': '4501',
#    'PERIMETER': 10297.328125,
#    'DNAME': 'เขตวังทองหลาง',
#    'OBJECTID': 168.0,
#    'SNAME': 'แขวงวังทองหลาง',
#    'SCODE': '104501',
#    'SCODE_BMA': '104501',
#    'PCODE': '10',
#    'SUBDIST_': 125,
#    'water': 133}},
#  {'geometry': <POLYGON ((100.446 13.731, 100.446 13.731, 100.446 13.731, 100.446 13.731, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 198,
#    'DCODE': '1022',
#    'AREA_': 3327407.568827,
#    'SUB_CODE': '2202',
#    'PERIMETER': 7732.729004,
#    'DNAME': 'เขตภาษีเจริญ',
#    'OBJECTID': 160.0,
#    'SNAME': 'แขวงบางด้วน',
#    'SCODE': '102202',
#    'SCODE_BMA': '102202',
#    'PCODE': '10',
#    'SUBDIST_': 207,
#    'water': 217}},
#  {'geometry': <POLYGON ((100.537 13.73, 100.537 13.729, 100.538 13.729, 100.538 13.729, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 199,
#    'DCODE': '1004',
#    'AREA_': 1515649.054937,
#    'SUB_CODE': '0402',
#    'PERIMETER': 7036.932617,
#    'DNAME': 'เขตบางรัก',
#    'OBJECTID': 161.0,
#    'SNAME': 'แขวงสีลม',
#    'SCODE': '100402',
#    'SCODE_BMA': '100402',
#    'PCODE': '10',
#    'SUBDIST_': 208,
#    'water': 52}},
#  {'geometry': <POLYGON ((100.516 13.8, 100.517 13.8, 100.518 13.8, 100.518 13.8, 100.519 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 109,
#    'DCODE': '1002',
#    'AREA_': 5616827.046241,
#    'SUB_CODE': '0206',
#    'PERIMETER': 10135.714844,
#    'DNAME': 'เขตดุสิต',
#    'OBJECTID': 162.0,
#    'SNAME': 'แขวงถนนนครไชยศรี',
#    'SCODE': '100206',
#    'SCODE_BMA': '100206',
#    'PCODE': '10',
#    'SUBDIST_': 119,
#    'water': 307}},
#  {'geometry': <POLYGON ((100.46 13.798, 100.461 13.798, 100.461 13.798, 100.463 13.797, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 110,
#    'DCODE': '1019',
#    'AREA_': 6246513.735849,
#    'SUB_CODE': '1902',
#    'PERIMETER': 12058.200195,
#    'DNAME': 'เขตตลิ่งชัน',
#    'OBJECTID': 163.0,
#    'SNAME': 'แขวงตลิ่งชัน',
#    'SCODE': '101902',
#    'SCODE_BMA': '101902',
#    'PCODE': '10',
#    'SUBDIST_': 120,
#    'water': 369}},
#  {'geometry': <POLYGON ((100.696 13.793, 100.696 13.793, 100.696 13.793, 100.696 13.793, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 111,
#    'DCODE': '1044',
#    'AREA_': 28068716.23108,
#    'SUB_CODE': '4401',
#    'PERIMETER': 25412.046875,
#    'DNAME': 'เขตสะพานสูง',
#    'OBJECTID': 164.0,
#    'SNAME': 'แขวงสะพานสูง',
#    'SCODE': '104401',
#    'SCODE_BMA': '104401',
#    'PCODE': '10',
#    'SUBDIST_': 121,
#    'water': 3913}},
#  {'geometry': <POLYGON ((100.494 13.798, 100.494 13.798, 100.494 13.798, 100.495 13.798, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 112,
#    'DCODE': '1025',
#    'AREA_': 3327452.239682,
#    'SUB_CODE': '2501',
#    'PERIMETER': 10569.723633,
#    'DNAME': 'เขตบางพลัด',
#    'OBJECTID': 166.0,
#    'SNAME': 'แขวงบางพลัด',
#    'SCODE': '102501',
#    'SCODE_BMA': '102501',
#    'PCODE': '10',
#    'SUBDIST_': 123,
#    'water': 214}},
#  {'geometry': <POLYGON ((100.537 13.798, 100.538 13.798, 100.538 13.798, 100.538 13.798, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 114,
#    'DCODE': '1014',
#    'AREA_': 9214687.864089,
#    'SUB_CODE': '1401',
#    'PERIMETER': 11976.791016,
#    'DNAME': 'เขตพญาไท',
#    'OBJECTID': 167.0,
#    'SNAME': 'แขวงสามเสนใน',
#    'SCODE': '101401',
#    'SCODE_BMA': '101401',
#    'PCODE': '10',
#    'SUBDIST_': 124,
#    'water': 301}},
#  {'geometry': <POLYGON ((100.517 13.71, 100.517 13.709, 100.517 13.709, 100.517 13.709, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 220,
#    'DCODE': '1031',
#    'AREA_': 1660672.895146,
#    'SUB_CODE': '3102',
#    'PERIMETER': 5373.89209,
#    'DNAME': 'เขตบางคอแหลม',
#    'OBJECTID': 210.0,
#    'SNAME': 'แขวงวัดพระยาไกร',
#    'SCODE': '103102',
#    'SCODE_BMA': '103102',
#    'PCODE': '10',
#    'SUBDIST_': 229,
#    'water': 162}},
#  {'geometry': <POLYGON ((100.687 13.705, 100.687 13.705, 100.687 13.705, 100.687 13.705, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 225,
#    'DCODE': '1032',
#    'AREA_': 16335585.296278,
#    'SUB_CODE': '3203',
#    'PERIMETER': 17823.169922,
#    'DNAME': 'เขตประเวศ',
#    'OBJECTID': 215.0,
#    'SNAME': 'แขวงดอกไม้',
#    'SCODE': '103203',
#    'SCODE_BMA': '103203',
#    'PCODE': '10',
#    'SUBDIST_': 234,
#    'water': 1387}},
#  {'geometry': <POLYGON ((100.574 13.79, 100.575 13.79, 100.575 13.79, 100.575 13.79, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 116,
#    'DCODE': '1017',
#    'AREA_': 4836701.495453,
#    'SUB_CODE': '1701',
#    'PERIMETER': 11768.671875,
#    'DNAME': 'เขตห้วยขวาง',
#    'OBJECTID': 170.0,
#    'SNAME': 'แขวงห้วยขวาง',
#    'SCODE': '101701',
#    'SCODE_BMA': '101701',
#    'PCODE': '10',
#    'SUBDIST_': 127,
#    'water': 457}},
#  {'geometry': <POLYGON ((100.495 13.785, 100.494 13.784, 100.493 13.784, 100.493 13.784, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 117,
#    'DCODE': '1025',
#    'AREA_': 2378712.373805,
#    'SUB_CODE': '2503',
#    'PERIMETER': 6913.351074,
#    'DNAME': 'เขตบางพลัด',
#    'OBJECTID': 171.0,
#    'SNAME': 'แขวงบางบำหรุ',
#    'SCODE': '102503',
#    'SCODE_BMA': '102503',
#    'PCODE': '10',
#    'SUBDIST_': 128,
#    'water': 63}},
#  {'geometry': <POLYGON ((100.452 13.675, 100.452 13.675, 100.452 13.675, 100.452 13.675, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 247,
#    'DCODE': '1021',
#    'AREA_': 73011220.866551,
#    'SUB_CODE': '2105',
#    'PERIMETER': 67636.585938,
#    'DNAME': 'เขตบางขุนเทียน',
#    'OBJECTID': 195.0,
#    'SNAME': 'แขวงท่าข้าม',
#    'SCODE': '102105',
#    'SCODE_BMA': '102101',
#    'PCODE': '10',
#    'SUBDIST_': 257,
#    'water': 25487}},
#  {'geometry': <POLYGON ((100.478 13.716, 100.479 13.715, 100.479 13.715, 100.479 13.714, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 298,
#    'DCODE': '1015',
#    'AREA_': 1721413.784824,
#    'SUB_CODE': '1506',
#    'PERIMETER': 6864.790527,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 209.0,
#    'SNAME': 'แขวงดาวคะนอง',
#    'SCODE': '101506',
#    'SCODE_BMA': '101506',
#    'PCODE': '10',
#    'SUBDIST_': 228,
#    'water': 97}},
#  {'geometry': <POLYGON ((100.426 13.712, 100.426 13.712, 100.426 13.712, 100.426 13.712, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 221,
#    'DCODE': '1040',
#    'AREA_': 6963669.741368,
# ...
#    'SUBDIST_': 191,
#    'water': 55}},
#  {'geometry': <POLYGON ((100.512 13.74, 100.513 13.74, 100.513 13.74, 100.513 13.74, 100.5...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 183,
#    'DCODE': '1013',
#    'AREA_': 397734.670107,
#    'SUB_CODE': '1303',
#    'PERIMETER': 3167.172119,
#    'DNAME': 'เขตสัมพันธวงศ์',
#    'OBJECTID': 189.0,
#    'SNAME': 'แขวงตลาดน้อย',
#    'SCODE': '101303',
#    'SCODE_BMA': '101303',
#    'PCODE': '10',
#    'SUBDIST_': 192,
#    'water': 27}},
#  {'geometry': <POLYGON ((100.447 13.682, 100.447 13.682, 100.447 13.682, 100.447 13.682, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 242,
#    'DCODE': '1021',
#    'AREA_': 49196873.075086,
#    'SUB_CODE': '2107',
#    'PERIMETER': 38737.773438,
#    'DNAME': 'เขตบางขุนเทียน',
#    'OBJECTID': 190.0,
#    'SNAME': 'แขวงแสมดำ',
#    'SCODE': '102107',
#    'SCODE_BMA': '102102',
#    'PCODE': '10',
#    'SUBDIST_': 252,
#    'water': 10190}},
#  {'geometry': <POLYGON ((100.515 13.719, 100.517 13.718, 100.517 13.718, 100.517 13.718, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 210,
#    'DCODE': '1028',
#    'AREA_': 1800256.553351,
#    'SUB_CODE': '2802',
#    'PERIMETER': 6891.965332,
#    'DNAME': 'เขตสาทร',
#    'OBJECTID': 204.0,
#    'SNAME': 'แขวงยานนาวา',
#    'SCODE': '102802',
#    'SCODE_BMA': '102802',
#    'PCODE': '10',
#    'SUBDIST_': 218,
#    'water': 142}},
#  {'geometry': <POLYGON ((100.493 13.721, 100.493 13.721, 100.493 13.721, 100.493 13.721, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 299,
#    'DCODE': '1015',
#    'AREA_': 1429526.070888,
#    'SUB_CODE': '1507',
#    'PERIMETER': 5720.271484,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 205.0,
#    'SNAME': 'แขวงสำเหร่',
#    'SCODE': '101507',
#    'SCODE_BMA': '101507',
#    'PCODE': '10',
#    'SUBDIST_': 219,
#    'water': 150}},
#  {'geometry': <POLYGON ((100.493 13.721, 100.494 13.721, 100.495 13.721, 100.495 13.721, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 211,
#    'DCODE': '1018',
#    'AREA_': 2284291.197504,
#    'SUB_CODE': '1803',
#    'PERIMETER': 5995.125,
#    'DNAME': 'เขตคลองสาน',
#    'OBJECTID': 206.0,
#    'SNAME': 'แขวงบางลำภูล่าง',
#    'SCODE': '101803',
#    'SCODE_BMA': '101803',
#    'PCODE': '10',
#    'SUBDIST_': 220,
#    'water': 222}},
#  {'geometry': <POLYGON ((100.503 13.745, 100.504 13.744, 100.504 13.744, 100.504 13.744, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 178,
#    'DCODE': '1013',
#    'AREA_': 497978.84431,
#    'SUB_CODE': '1301',
#    'PERIMETER': 2835.666992,
#    'DNAME': 'เขตสัมพันธวงศ์',
#    'OBJECTID': 207.0,
#    'SNAME': 'แขวงจักรวรรดิ์',
#    'SCODE': '101301',
#    'SCODE_BMA': '101301',
#    'PCODE': '10',
#    'SUBDIST_': 187,
#    'water': 32}},
#  {'geometry': <POLYGON ((100.517 13.71, 100.517 13.71, 100.517 13.711, 100.518 13.711, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 219,
#    'DCODE': '1028',
#    'AREA_': 2482433.092815,
#    'SUB_CODE': '2801',
#    'PERIMETER': 7289.75293,
#    'DNAME': 'เขตสาทร',
#    'OBJECTID': 208.0,
#    'SNAME': 'แขวงทุ่งวัดดอน',
#    'SCODE': '102801',
#    'SCODE_BMA': '102801',
#    'PCODE': '10',
#    'SUBDIST_': 227,
#    'water': 64}},
#  {'geometry': <POLYGON ((100.516 13.757, 100.517 13.756, 100.517 13.755, 100.517 13.755, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 154,
#    'DCODE': '1008',
#    'AREA_': 582558.009057,
#    'SUB_CODE': '0803',
#    'PERIMETER': 3054.08667,
#    'DNAME': 'เขตป้อมปราบศัตรูพ่าย',
#    'OBJECTID': 221.0,
#    'SNAME': 'แขวงคลองมหานาค',
#    'SCODE': '100803',
#    'SCODE_BMA': '100803',
#    'PCODE': '10',
#    'SUBDIST_': 164,
#    'water': 8}},
#  {'geometry': <POLYGON ((100.499 13.756, 100.499 13.756, 100.499 13.755, 100.499 13.755, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 156,
#    'DCODE': '1001',
#    'AREA_': 149628.359536,
#    'SUB_CODE': '0105',
#    'PERIMETER': 1669.97876,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 223.0,
#    'SNAME': 'แขวงศาลเจ้าพ่อเสือ',
#    'SCODE': '100105',
#    'SCODE_BMA': '100105',
#    'PCODE': '10',
#    'SUBDIST_': 166,
#    'water': 0}},
#  {'geometry': <POLYGON ((100.506 13.756, 100.506 13.756, 100.507 13.756, 100.508 13.756, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 157,
#    'DCODE': '1008',
#    'AREA_': 402774.104143,
#    'SUB_CODE': '0804',
#    'PERIMETER': 3022.940918,
#    'DNAME': 'เขตป้อมปราบศัตรูพ่าย',
#    'OBJECTID': 224.0,
#    'SNAME': 'แขวงบ้านบาตร',
#    'SCODE': '100804',
#    'SCODE_BMA': '100804',
#    'PCODE': '10',
#    'SUBDIST_': 167,
#    'water': 2}},
#  {'geometry': <POLYGON ((100.502 13.755, 100.502 13.753, 100.502 13.752, 100.502 13.752, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 158,
#    'DCODE': '1001',
#    'AREA_': 153714.193517,
#    'SUB_CODE': '0106',
#    'PERIMETER': 1587.676636,
#    'DNAME': 'เขตพระนคร',
#    'OBJECTID': 225.0,
#    'SNAME': 'แขวงเสาชิงช้า',
#    'SCODE': '100106',
#    'SCODE_BMA': '100106',
#    'PCODE': '10',
#    'SUBDIST_': 168,
#    'water': 1}},
#  {'geometry': <POLYGON ((100.591 13.729, 100.591 13.729, 100.591 13.729, 100.591 13.728, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 200,
#    'DCODE': '1039',
#    'AREA_': 3536310.073223,
#    'SUB_CODE': '3903',
#    'PERIMETER': 9479.078125,
#    'DNAME': 'เขตวัฒนา',
#    'OBJECTID': 227.0,
#    'SNAME': 'แขวงพระโขนงเหนือ',
#    'SCODE': '103903',
#    'SCODE_BMA': '103903',
#    'PCODE': '10',
#    'SUBDIST_': 209,
#    'water': 107}},
#  {'geometry': <POLYGON ((100.578 13.725, 100.578 13.725, 100.578 13.725, 100.578 13.725, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 206,
#    'DCODE': '1033',
#    'AREA_': 3806016.240957,
#    'SUB_CODE': '3303',
#    'PERIMETER': 10397.668945,
#    'DNAME': 'เขตคลองเตย',
#    'OBJECTID': 232.0,
#    'SNAME': 'แขวงพระโขนง',
#    'SCODE': '103303',
#    'SCODE_BMA': '103303',
#    'PCODE': '10',
#    'SUBDIST_': 214,
#    'water': 131}},
#  {'geometry': <POLYGON ((100.455 13.723, 100.455 13.723, 100.455 13.722, 100.455 13.721, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 213,
#    'DCODE': '1022',
#    'AREA_': 6224145.814559,
#    'SUB_CODE': '2201',
#    'PERIMETER': 14777.029297,
#    'DNAME': 'เขตภาษีเจริญ',
#    'OBJECTID': 234.0,
#    'SNAME': 'แขวงบางหว้า',
#    'SCODE': '102201',
#    'SCODE_BMA': '102201',
#    'PCODE': '10',
#    'SUBDIST_': 216,
#    'water': 494}},
#  {'geometry': <POLYGON ((100.479 13.723, 100.479 13.723, 100.479 13.722, 100.479 13.722, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 203,
#    'DCODE': '1015',
#    'AREA_': 1500698.511761,
#    'SUB_CODE': '1505',
#    'PERIMETER': 5595.015137,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 235.0,
#    'SNAME': 'แขวงตลาดพลู',
#    'SCODE': '101505',
#    'SCODE_BMA': '101505',
#    'PCODE': '10',
#    'SUBDIST_': 217,
#    'water': 40}},
#  {'geometry': <POLYGON ((100.502 13.702, 100.502 13.702, 100.502 13.701, 100.502 13.701, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 227,
#    'DCODE': '1031',
#    'AREA_': 2092642.650558,
#    'SUB_CODE': '3101',
#    'PERIMETER': 5718.263184,
#    'DNAME': 'เขตบางคอแหลม',
#    'OBJECTID': 236.0,
#    'SNAME': 'แขวงบางคอแหลม',
#    'SCODE': '103101',
#    'SCODE_BMA': '103101',
#    'PCODE': '10',
#    'SUBDIST_': 237,
#    'water': 304}},
#  {'geometry': <POLYGON ((100.65 13.703, 100.65 13.703, 100.65 13.703, 100.65 13.703, 100.6...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 228,
#    'DCODE': '1032',
#    'AREA_': 12885062.788437,
#    'SUB_CODE': '3202',
#    'PERIMETER': 15210.699219,
#    'DNAME': 'เขตประเวศ',
#    'OBJECTID': 237.0,
#    'SNAME': 'แขวงหนองบอน',
#    'SCODE': '103202',
#    'SCODE_BMA': '103202',
#    'PCODE': '10',
#    'SUBDIST_': 238,
#    'water': 1610}},
#  {'geometry': <POLYGON ((100.465 13.703, 100.466 13.703, 100.466 13.703, 100.466 13.703, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 230,
#    'DCODE': '1035',
#    'AREA_': 5235178.312194,
#    'SUB_CODE': '3504',
#    'PERIMETER': 14032.870117,
#    'DNAME': 'เขตจอมทอง',
#    'OBJECTID': 239.0,
#    'SNAME': 'แขวงจอมทอง',
#    'SCODE': '103504',
#    'SCODE_BMA': '103504',
#    'PCODE': '10',
#    'SUBDIST_': 240,
#    'water': 436}},
#  {'geometry': <POLYGON ((100.347 13.698, 100.347 13.698, 100.347 13.698, 100.347 13.698, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 231,
#    'DCODE': '1023',
#    'AREA_': 19366364.976066,
#    'SUB_CODE': '2302',
#    'PERIMETER': 19451.849609,
#    'DNAME': 'เขตหนองแขม',
#    'OBJECTID': 240.0,
#    'SNAME': 'แขวงหนองแขม',
#    'SCODE': '102302',
#    'SCODE_BMA': '102301',
#    'PCODE': '10',
#    'SUBDIST_': 241,
#    'water': 3209}},
#  {'geometry': <POLYGON ((100.531 13.699, 100.532 13.699, 100.532 13.699, 100.532 13.698, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 232,
#    'DCODE': '1012',
#    'AREA_': 5185711.212244,
#    'SUB_CODE': '1204',
#    'PERIMETER': 10494.548828,
#    'DNAME': 'เขตยานนาวา',
#    'OBJECTID': 241.0,
#    'SNAME': 'แขวงบางโพงพาง',
#    'SCODE': '101204',
#    'SCODE_BMA': '101202',
#    'PCODE': '10',
#    'SUBDIST_': 242,
#    'water': 300}},
#  {'geometry': <POLYGON ((100.49 13.695, 100.49 13.695, 100.49 13.695, 100.49 13.693, 100.4...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 233,
#    'DCODE': '1024',
#    'AREA_': 7223309.584137,
#    'SUB_CODE': '2402',
#    'PERIMETER': 14658.810547,
#    'DNAME': 'เขตราษฎร์บูรณะ',
#    'OBJECTID': 242.0,
#    'SNAME': 'แขวงบางปะกอก',
#    'SCODE': '102402',
#    'SCODE_BMA': '102402',
#    'PCODE': '10',
#    'SUBDIST_': 243,
#    'water': 1016}},
#  {'geometry': <POLYGON ((100.438 13.693, 100.438 13.693, 100.438 13.693, 100.439 13.693, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 234,
#    'DCODE': '1050',
#    'AREA_': 35857312.087152,
#    'SUB_CODE': '5001',
#    'PERIMETER': 32563.806641,
#    'DNAME': 'เขตบางบอน',
#    'OBJECTID': 243.0,
#    'SNAME': 'แขวงบางบอน',
#    'SCODE': '105001',
#    'SCODE_BMA': '105001',
#    'PCODE': '10',
#    'SUBDIST_': 244,
#    'water': 5140}},
#  {'geometry': <POLYGON ((100.469 13.687, 100.469 13.687, 100.47 13.687, 100.47 13.687, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 237,
#    'DCODE': '1035',
#    'AREA_': 8818900.347762,
#    'SUB_CODE': '3503',
#    'PERIMETER': 15077.988281,
#    'DNAME': 'เขตจอมทอง',
#    'OBJECTID': 246.0,
#    'SNAME': 'แขวงบางมด',
#    'SCODE': '103503',
#    'SCODE_BMA': '103503',
#    'PCODE': '10',
#    'SUBDIST_': 247,
#    'water': 649}},
#  {'geometry': <POLYGON ((100.506 13.684, 100.506 13.684, 100.506 13.684, 100.506 13.684, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 239,
#    'DCODE': '1024',
#    'AREA_': 5109869.948991,
#    'SUB_CODE': '2401',
#    'PERIMETER': 11432.702148,
#    'DNAME': 'เขตราษฎร์บูรณะ',
#    'OBJECTID': 248.0,
#    'SNAME': 'แขวงราษฎร์บูรณะ',
#    'SCODE': '102401',
#    'SCODE_BMA': '102401',
#    'PCODE': '10',
#    'SUBDIST_': 249,
#    'water': 416}},
#  {'geometry': <POLYGON ((100.589 13.683, 100.59 13.683, 100.591 13.682, 100.592 13.682, 10...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 240,
#    'DCODE': '1047',
#    'AREA_': 18947568.345526,
#    'SUB_CODE': '4701',
#    'PERIMETER': 22441.208984,
#    'DNAME': 'เขตบางนา',
#    'OBJECTID': 249.0,
#    'SNAME': 'แขวงบางนา',
#    'SCODE': '104701',
#    'SCODE_BMA': '104701',
#    'PCODE': '10',
#    'SUBDIST_': 250,
#    'water': 755}},
#  {'geometry': <POLYGON ((100.491 13.721, 100.491 13.719, 100.49 13.718, 100.49 13.716, 100...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 212,
#    'DCODE': '1015',
#    'AREA_': 1383325.068772,
#    'SUB_CODE': '1504',
#    'PERIMETER': 5013.928711,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 251.0,
#    'SNAME': 'แขวงบุคคโล',
#    'SCODE': '101504',
#    'SCODE_BMA': '101504',
#    'PCODE': '10',
#    'SUBDIST_': 221,
#    'water': 33}},
#  {'geometry': <POLYGON ((100.555 13.706, 100.554 13.705, 100.553 13.704, 100.552 13.704, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 215,
#    'DCODE': '1012',
#    'AREA_': 7319099.244571,
#    'SUB_CODE': '1203',
#    'PERIMETER': 13540.798828,
#    'DNAME': 'เขตยานนาวา',
#    'OBJECTID': 253.0,
#    'SNAME': 'แขวงช่องนนทรีย์',
#    'SCODE': '101203',
#    'SCODE_BMA': '101201',
#    'PCODE': '10',
#    'SUBDIST_': 223,
#    'water': 595}},
#  {'geometry': <POLYGON ((100.493 13.725, 100.493 13.725, 100.493 13.725, 100.493 13.725, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 201,
#    'DCODE': '1018',
#    'AREA_': 1721371.230827,
#    'SUB_CODE': '1804',
#    'PERIMETER': 6057.014648,
#    'DNAME': 'เขตคลองสาน',
#    'OBJECTID': 228.0,
#    'SNAME': 'แขวงคลองต้นไทร',
#    'SCODE': '101804',
#    'SCODE_BMA': '101804',
#    'PCODE': '10',
#    'SUBDIST_': 210,
#    'water': 113}},
#  {'geometry': <POLYGON ((100.486 13.728, 100.487 13.727, 100.487 13.727, 100.488 13.727, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 203,
#    'DCODE': '1015',
#    'AREA_': 1026111.04245,
#    'SUB_CODE': '1503',
#    'PERIMETER': 4801.162109,
#    'DNAME': 'เขตธนบุรี',
#    'OBJECTID': 230.0,
#    'SNAME': 'แขวงบางยี่เรือ',
#    'SCODE': '101503',
#    'SCODE_BMA': '101503',
#    'PCODE': '10',
#    'SUBDIST_': 212,
#    'water': 9}},
#  {'geometry': <POLYGON ((100.545 13.726, 100.545 13.726, 100.545 13.726, 100.546 13.726, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 205,
#    'DCODE': '1028',
#    'AREA_': 2976469.469236,
#    'SUB_CODE': '2803',
#    'PERIMETER': 8405.631836,
#    'DNAME': 'เขตสาทร',
#    'OBJECTID': 231.0,
#    'SNAME': 'แขวงทุ่งมหาเมฆ',
#    'SCODE': '102803',
#    'SCODE_BMA': '102803',
#    'PCODE': '10',
#    'SUBDIST_': 213,
#    'water': 110}},
#  {'geometry': <POLYGON ((100.469 13.716, 100.469 13.716, 100.469 13.716, 100.469 13.716, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 218,
#    'DCODE': '1035',
#    'AREA_': 2822070.331285,
#    'SUB_CODE': '3502',
#    'PERIMETER': 10126.459961,
#    'DNAME': 'เขตจอมทอง',
#    'OBJECTID': 256.0,
#    'SNAME': 'แขวงบางค้อ',
#    'SCODE': '103502',
#    'SCODE_BMA': '103502',
#    'PCODE': '10',
#    'SUBDIST_': 226,
#    'water': 186}},
#  {'geometry': <POLYGON ((100.503 13.644, 100.503 13.644, 100.503 13.644, 100.503 13.644, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 264,
#    'DCODE': '1049',
#    'AREA_': 21781467.104052,
#    'SUB_CODE': '4902',
#    'PERIMETER': 23263.503906,
#    'DNAME': 'เขตทุ่งครุ',
#    'OBJECTID': 260.0,
#    'SNAME': 'แขวงทุ่งครุ',
#    'SCODE': '104902',
#    'SCODE_BMA': '104902',
#    'PCODE': '10',
#    'SUBDIST_': 273,
#    'water': 2970}},
#  {'geometry': <POLYGON ((100.676 13.852, 100.676 13.852, 100.676 13.852, 100.676 13.852, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 78,
#    'DCODE': '1043',
#    'AREA_': 12748830.227235,
#    'SUB_CODE': '4301',
#    'PERIMETER': 17692.277344,
#    'DNAME': 'เขตคันนายาว',
#    'OBJECTID': 294.0,
#    'SNAME': 'แขวงคันนายาว',
#    'SCODE': '104301',
#    'SCODE_BMA': '104301',
#    'PCODE': '10',
#    'SUBDIST_': 82,
#    'water': 1973}},
#  {'geometry': <POLYGON ((100.787 13.931, 100.791 13.931, 100.792 13.931, 100.792 13.931, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 41,
#    'DCODE': '1046',
#    'AREA_': 43206264.908346,
#    'SUB_CODE': '4602',
#    'PERIMETER': 27065.855469,
#    'DNAME': 'เขตคลองสามวา',
#    'OBJECTID': 296.0,
#    'SNAME': 'แขวงสามวาตะวันออก',
#    'SCODE': '104602',
#    'SCODE_BMA': '104602',
#    'PCODE': '10',
#    'SUBDIST_': 42,
#    'water': 14188}},
#  {'geometry': <POLYGON ((100.609 13.786, 100.613 13.784, 100.614 13.784, 100.615 13.783, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 104,
#    'DCODE': '1045',
#    'AREA_': 6837565.146343,
#    'SUB_CODE': '4504',
#    'PERIMETER': 11871.859375,
#    'DNAME': 'เขตวังทองหลาง',
#    'OBJECTID': 297.0,
#    'SNAME': 'แขวงพลับพลา',
#    'SCODE': '104504',
#    'SCODE_BMA': '104504',
#    'PCODE': '10',
#    'SUBDIST_': 130,
#    'water': 145}},
#  {'geometry': <POLYGON ((100.476 13.662, 100.476 13.662, 100.476 13.662, 100.476 13.662, 1...>,
#   'properties': {'PNAME': 'กรุงเทพมหานคร',
#    'SUBDIST_ID': 253,
#    'DCODE': '1049',
#    'AREA_': 11169225.103283,
#    'SUB_CODE': '4901',
#    'PERIMETER': 18919.382812,
#    'DNAME': 'เขตทุ่งครุ',
#    'OBJECTID': 287.0,
#    'SNAME': 'แขวงบางมด',
#    'SCODE': '104901',
#    'SCODE_BMA': '104901',
#    'PCODE': '10',
#    'SUBDIST_': 263,
#    'water': 1158}}]

# %%
spark.stop()
