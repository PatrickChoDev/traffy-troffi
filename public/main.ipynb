# %%
import pandas as pd

# %%
import ast

df = pd.read_csv("bangkok_district.csv")

# %%
list_columns = [
    "District_Place_of_worship",
    "District_Education_location",
    "District_Cultural_heritage",
    "District_Commercial_areas",
    "District_Transportation",
    "District_Agency"
]

for col in list_columns:
    df[col] = df[col].apply(ast.literal_eval)

# %%
df
# Out:
#     District_Thai_Name District_English_Name  District_Postal_Code  \
# 0               พระนคร           Phra Nakhon                 10200
# 1               พระนคร           Phra Nakhon                 10200
# 2               พระนคร           Phra Nakhon                 10200
# 3               พระนคร           Phra Nakhon                 10200
# 4               พระนคร           Phra Nakhon                 10200
# ..                 ...                   ...                   ...
# 175            ทุ่งครุ            Thung Khru                 10140
# 176             บางบอน              Bang Bon                 10150
# 177             บางบอน              Bang Bon                 10150
# 178             บางบอน              Bang Bon                 10150
# 179             บางบอน              Bang Bon                 10150
#
#      District_Geocode                            District_Office_Address  \
# 0                1001  เลขที่ 78 ซอยสามเสน 3 (วัดสามพระยา) ถนนสามเสน ...
# ...

# %%
df["District_Place_of_worship"][0][0]
# Out:
# 'วัดพระศรีรัตนศาสดาราม'
